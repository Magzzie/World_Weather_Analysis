# %%
# Import the dependencies. 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
coordinates
# Out:
# [(-53.43037100555974, 166.21708041472158),
#  (34.06260786769073, -32.09887002555817),
#  (-27.33640098234953, 86.07337517949696),
#  (71.15334270598336, 85.39562342738964),
#  (-32.91240530362958, 69.60218790232437),
#  (9.270779336430891, -90.25949239505742),
#  (42.10714585309077, 179.00597115140857),
#  (12.889389406739653, 96.91574697386847),
#  (15.767164982931106, 93.36935691883025),
#  (-67.81591953407361, -38.9664857481128),
#  (85.75178140637868, 92.87216775755081),
#  (87.15151564278352, -97.35856433732751),
#  (40.573834975364065, 100.2247655717826),
#  (29.437481471925125, -153.15256574495487),
#  (-43.7766631858919, 27.650470019796217),
#  (-30.912274880453793, 28.07603517676202),
#  (33.15819638412084, 35.9111146762765),
#  (49.24730953054032, -58.25795612728854),
#  (-29.95358377069875, -72.43435936244127),
#  (-3.5565745274086424, 27.562507686219618),
#  (-48.747615245106545, 11.466475293860356),
#  (89.1086599792672, -165.97238040875925),
# ...

# %%
# Import citipy module. 
from citipy import citipy

# %%
# Create a list for holding the cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count. 
len(cities)
# Out:
# 615

# %%
print(cities)
# Out:
# ['bluff', 'ribeira grande', 'carnarvon', 'dudinka', 'mahebourg', 'la libertad', 'nikolskoye', 'mergui', 'labutta', 'ushuaia', 'khatanga', 'qaanaaq', 'zhangye', 'kahului', 'port elizabeth', 'elliot', 'nawa', 'corner brook', 'coquimbo', 'kampene', 'hermanus', 'barrow', 'namibe', 'inhambane', 'idah', 'atuona', 'norman wells', 'rocha', 'tsihombe', 'rikitea', 'findlay', 'richards bay', 'kodinsk', 'tiarei', 'marrakesh', 'rajgurunagar', 'oruro', 'burgeo', 'samusu', 'busselton', 'nirsa', 'isangel', 'sakakah', 'vaini', 'hasaki', 'udachnyy', 'tessalit', 'port alfred', 'sitka', 'tuktoyaktuk', 'albany', 'tiksi', 'ponta do sol', 'west bay', 'bac lieu', 'mareeba', 'saint-augustin', 'hilo', 'barentsburg', 'broken hill', 'cherskiy', 'cape town', 'castro', 'aykhal', 'mataura', 'bethel', 'jamestown', 'gardenstown', 'faanui', 'magadan', 'mar del plata', 'paramonga', 'dikson', 'puli', 'yellowknife', 'iquique', 'chokurdakh', 'henties bay', 'punta arenas', 'kapaa', 'tuatapere', 'touros', 'oriximina', 'xiq
# ...

# %% [markdown]
# ## Get the City Weather Data

# %%
# Import dependencies.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library. 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters. 
record_count = 1 
set_count = 1

# Loop through all the cities in our list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | dudinka
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | la libertad
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | mergui
# Processing Record 9 of Set 1 | labutta
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | zhangye
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | elliot
# Processing Record 17 of Set 1 | nawa
# Processing Record 18 of Set 1 | corner brook
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | kampene
# Processing Record 21 of Set 1 | hermanus
# ...

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters. 
record_count = 1 
set_count = 1

# Loop through all the cities in our list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1
    
    # Run an API request for each of the cities. 
    try: 
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard. 
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete. 
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | dudinka
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | la libertad
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | zhangye
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | elliot
# Processing Record 17 of Set 1 | nawa
# Processing Record 18 of Set 1 | corner brook
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | kampene
# ...

# %% [markdown]
# ## Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bluff -46.6000  168.3333     48.63        64         100
# 1  Ribeira Grande  38.5167  -28.7000     63.00        88          20
# 2       Carnarvon -24.8667  113.6333     68.07       100          75
# 3         Dudinka  69.4058   86.1778     20.62        97         100
# 4       Mahebourg -20.4081   57.7000     79.25        73          20
# 5     La Libertad  -2.2333  -80.9000     83.86        74           0
# 6      Nikolskoye  59.7035   30.7861     25.72        96          15
# 7         Ushuaia -54.8000  -68.3000     53.26        47          20
# 8        Khatanga  71.9667  102.5000     -6.47       100          81
# 9         Qaanaaq  77.4840  -69.3632     25.09        71         100
#
#    Wind Speed Country                 Date
# 0        8.90      NZ  2022-03-31 20:17:20
# 1       16.11      PT  2022-03-31 20:17:17
# 2       21.85      AU  2022-03-31 20:17:21
# ...

# %%
# Reorder the columns in the DataFrame. 
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0           Bluff      NZ  2022-03-31 20:17:20 -46.6000  168.3333     48.63
# 1  Ribeira Grande      PT  2022-03-31 20:17:17  38.5167  -28.7000     63.00
# 2       Carnarvon      AU  2022-03-31 20:17:21 -24.8667  113.6333     68.07
# 3         Dudinka      RU  2022-03-31 20:17:22  69.4058   86.1778     20.62
# 4       Mahebourg      MU  2022-03-31 20:17:22 -20.4081   57.7000     79.25
# 5     La Libertad      EC  2022-03-31 20:17:23  -2.2333  -80.9000     83.86
# 6      Nikolskoye      RU  2022-03-31 20:17:24  59.7035   30.7861     25.72
# 7         Ushuaia      AR  2022-03-31 20:15:21 -54.8000  -68.3000     53.26
# 8        Khatanga      RU  2022-03-31 20:17:25  71.9667  102.5000     -6.47
# 9         Qaanaaq      GL  2022-03-31 20:17:26  77.4840  -69.3632     25.09
#
#    Humidity  Cloudiness  Wind Speed
# 0        64         100        8.90
# 1        88          20       16.11
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Scatter Plots for Latitude vs Weather Parameters
# Focus: Climate Change

# %%
# recall the DataFrame without rerunning the code and changing coordinates.
file_to_load = "weather_data/cities.csv"
# Read the CSV file into a DataFrame.
city_data_df = pd.read_csv(file_to_load)
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0           Bluff      NZ  2022-03-31 20:17:20 -46.6000  168.3333
# 1        1  Ribeira Grande      PT  2022-03-31 20:17:17  38.5167  -28.7000
# 2        2       Carnarvon      AU  2022-03-31 20:17:21 -24.8667  113.6333
# 3        3         Dudinka      RU  2022-03-31 20:17:22  69.4058   86.1778
# 4        4       Mahebourg      MU  2022-03-31 20:17:22 -20.4081   57.7000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     48.63        64         100        8.90
# 1     63.00        88          20       16.11
# 2     68.07       100          75       21.85
# 3     20.62        97         100        1.28
# 4     79.25        73          20       13.80

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %% [markdown]
# ### Latitude vs. Max Temp Scatter Plot

# %%
# Import time module. 
import time 

# Build the scatter plot for latitude vs. max temperature. 
plt.scatter(lats,
           max_temp,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show the plot.
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Scatter Plot

# %%
# Build the scatter plot for latitude vs. humidity. 
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidth=1, marker="o",
           color="lightgreen", alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show the plot.
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Scatter Plot

# %%
# Build the scatter plot for latitude vs. cloudiness. 
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           color="gold", alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show the plot.
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Scatter Plot

# %%
# Build the scatter plot for latitude vs. wind speed. 
plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           color="coral", alpha=0.8, label="Cities")

# Incorporate the other graph properties. 
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show the plot.
plt.show()

# %% [markdown]
# ## Linear Regression Analysis

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to perform linear regression on the weather data
# and plot a regression line and the equation with the data. 
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data. 
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create a scatter plot and plot the regression line. 
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    # Annotate the text for teh line equation. 
    plt.annotate(line_eq, text_coordinates, fontsize=15, color='red')
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# ### Northern and Southern Hemispheres DataFrames

# %%
# Test the loc method on the city DataFrame.
index13 = city_data_df.loc[13]
index13
# Out:
# City_ID                        13
# City                       Elliot
# Country                        ZA
# Date          2022-03-31 20:17:28
# Lat                      -31.3333
# Lng                         27.85
# Max Temp                     58.1
# Humidity                       99
# Cloudiness                    100
# Wind Speed                   2.19
# Name: 13, dtype: object

# %%
# Test filtering the DataFrame for northern latitudes. 
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 559    False
# 560     True
# 561     True
# 562     True
# 563     True
# Name: Lat, Length: 564, dtype: bool

# %%
# Test Return a DataFrame by filter the DataFrame for northern latitudes using the loc method.
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 1        1  Ribeira Grande      PT  2022-03-31 20:17:17  38.5167  -28.7000
# 3        3         Dudinka      RU  2022-03-31 20:17:22  69.4058   86.1778
# 6        6      Nikolskoye      RU  2022-03-31 20:17:24  59.7035   30.7861
# 8        8        Khatanga      RU  2022-03-31 20:17:25  71.9667  102.5000
# 9        9         Qaanaaq      GL  2022-03-31 20:17:26  77.4840  -69.3632
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 1     63.00        88          20       16.11
# 3     20.62        97         100        1.28
# 6     25.72        96          15        1.97
# 8     -6.47       100          81        4.88
# 9     25.09        71         100        4.99

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# ### Linear Regression on the Max Temp for the Northern & Southern Hemispheres

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp', (10, -20))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: -0.893

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp', (-25, 45))
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.622

# %% [markdown]
# ### Linear Regression on the Percent Humidity for the Northern & Southern Hemispheres

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity', (43, 8))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.351

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity', (-25, 15))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.423

# %% [markdown]
# ### Linear Regression on the Percent Cloudiness for the Northern & Southern Hemispheres

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness', (37, 47))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.313

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness', (-55, 60))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.180

# %% [markdown]
# ### Linear Regression on the Wind Speed for the Northern & Southern Hemispheres

# %%
# Linear regression on the Northern Hemisphere. 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed (mph)', (45, 28))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: 0.024

# %%
# Linear regression on the Southern Hemisphere. 
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed (mph)', (-25, 29))

# Get correlation coefficient value for the plot.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print(f"The r-value is: {r_value:.3f}")
# Out:
# The r-value is: -0.344

# %% [markdown]
# ## Heatmaps for Weather Parameters
