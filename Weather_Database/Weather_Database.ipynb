# %%
# Import the dependencies. 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Import citipy module. 
from citipy import citipy

# %%
# Create a list for holding the cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count. 
len(cities)
# Out:
# 742

# %%
print(cities)
# Out:
# ['kapaa', 'la cruz', 'acapulco', 'butaritari', 'mys shmidta', 'nizhneyansk', 'tafo', 'pundaguitan', 'port alfred', 'barentsburg', 'porterville', 'saskylakh', 'marcona', 'rikitea', 'asfi', 'broken hill', 'albany', 'castro', 'ushuaia', 'fortuna', 'sohag', 'puerto ayora', 'bambous virieux', 'atuona', 'tuktoyaktuk', 'jamestown', 'barrow', 'burica', 'margate', 'thompson', 'bonavista', 'airai', 'hobart', 'pevek', 'qaanaaq', 'georgetown', 'dingle', 'hermanus', 'busselton', 'devonport', 'tiksi', 'tasiilaq', 'punta arenas', 'faya', 'mitsamiouli', 'agadez', 'taolanaro', 'vaini', 'avarua', 'bose', 'saint george', 'yellowknife', 'kamenskoye', 'cefalu', 'sitka', 'nikolskoye', 'ribeira grande', 'cap malheureux', 'ambodifototra', 'skalistyy', 'arraial do cabo', 'victoria', 'bubaque', 'esperance', 'cape town', 'port elizabeth', 'luderitz', 'ponta do sol', 'crossville', 'mar del plata', 'new norfolk', 'bluff', 'tuatapere', 'torbay', 'san quintin', 'hofn', 'north bend', 'sentyabrskiy', 'hasaki', 'camalu', 'kodinsk', 'yumen', 'charters towers', 'katsuura', 'neyshabur', 'chapadinha', 'pisco', 'amderma', 'severo-kurilsk', 'portland', 'sisak', 'umea', 'vardo', 'high level', 'kamenka', 'deputatskiy', 'longyearbyen', 'neiva', 'lebu', 'chokurdakh', 'merauke', 'naze', 'bredasdorp', 'savelugu', 'namtsy', 'kaitangata', 'hokitika', 'hutchinson', 'vostok', 'xining', 'tiznit', 'igarka', 'silifke', 'scottsburgh', 'bairiki', 'makakilo city', 'attawapiskat', 'chimbote', 'buala', 'guthrie', 'upernavik', 'college', 'bauchi', 'nome', 'mataura', 'saldanha', 'hilo', 'ambanja', 'ahipara', 'riyadh', 'karasuk', 'batsfjord', 'kruisfontein', 'owando', 'kysyl-syr', 'constitucion', 'belushya guba', 'dryden', 'dikson', 'puerto del rosario', 'macas', 'provideniya', 'nehe', 'manama', 'khatanga', 'waingapu', 'cherskiy', 'tura', 'acarau', 'nim ka thana', 'baoshan', 'nurota', 'yar-sale', 'cairns', 'russell', 'paamiut', 'barbar', 'kaeo', 'andevoranto', 'nemuro', 'kavieng', 'vaitupu', 'vila velha', 'hami', 'mocambique', 'tsihombe', 'lasa', 'am timan', 'victoria falls', 'westport', 'husavik', 'bad doberan', 'winnemucca', 'antalaha', 'faanui', 'labytnangi', 'daye', 'sao filipe', 'talnakh', 'khandyga', 'mount gambier', 'moron', 'uvelskiy', 'sampit', 'ajaccio', 'pierre', 'saint-augustin', 'kencong', 'fujinomiya', 'necochea', 'hrastnik', 'nagato', 'saint-philippe', 'illoqqortoormiut', 'masvingo', 'pavlivka', 'san jeronimo', 'grand river south east', 'moose factory', 'isangel', 'sao lourenco do sul', 'meulaboh', 'puerto leguizamo', 'jacareacanga', 'visby', 'talaya', 'altay', 'vieux fort', 'souillac', 'halalo', 'hithadhoo', 'lashio', 'viligili', 'dombarovskiy', 'sinop', 'utiroa', 'magnolia', 'san isidro', 'valcourt', 'northam', 'dicabisagan', 'matveyevka', 'bintulu', 'cabo san lucas', 'hervey bay', 'ouango', 'ilulissat', 'mathbaria', 'baykit', 'vanimo', 'akdepe', 'teguise', 'huarmey', 'mount isa', 'namyslow', 'hualmay', 'melo', 'westerland', 'galiwinku', 'norman wells', 'newnan', 'waslala', 'moerai', 'porteirinha', 'batticaloa', 'santa cruz de tenerife', 'brejo santo', 'milove', 'mahebourg', 'hamilton', 'lethem', 'roald', 'mandalgovi', 'san miguel', 'gidole', 'sosnovka', 'bull savanna', 'liberal', 'east london', 'bengkulu', 'mahajanga', 'berlevag', 'carballo', 'playa vicente', 'taft', 'chapais', 'maldonado', 'maravatio', 'haibowan', 'pechora', 'langres', 'bima', 'geraldton', 'kailua', 'nalut', 'lalmohan', 'samarai', 'santiago del estero', 'camacha', 'arlit', 'belyy yar', 'houma', 'aykhal', 'letlhakeng', 'panguna', 'hunza', 'yenagoa', 'kozachi laheri', 'havoysund', 'ailigandi', 'lagoa', 'saint-louis', 'atar', 'anadyr', 'kirakira', 'hirara', 'chuy', 'adre', 'labuan', 'berga', 'tartus', 'beinamar', 'alice', 'cockburn town', 'katobu', 'skjervoy', 'ulyanovo', 'houston', 'alofi', 'litovko', 'bonthe', 'klaksvik', 'marshall', 'ginda', 'novyy urengoy', 'grindavik', 'lolua', 'salalah', 'bon accord', 'mangrol', 'conde', 'biak', 'stillwater', 'bolungarvik', 'paradwip', 'la asuncion', 'dekoa', 'kikw ...

# %%
# Import dependencies.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library. 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters. 
record_count = 1 
set_count = 1

# Loop through all the cities in our list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1
    
    # Run an API request for each of the cities. 
    try: 
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description= city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard. 
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description,
                         "Country": city_country,
                         "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete. 
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | la cruz
# Processing Record 3 of Set 1 | acapulco
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 1 | tafo
# Processing Record 8 of Set 1 | pundaguitan
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | porterville
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | asfi
# Processing Record 16 of Set 1 | broken hill
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | sohag
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | burica
# City not found. Skipping...
# Processing Record 29 of Set 1 | margate
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | bonavista
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | dingle
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | devonport
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | faya
# Processing Record 45 of Set 1 | mitsamiouli
# Processing Record 46 of Set 1 | agadez
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | bose
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 2 | cefalu
# Processing Record 5 of Set 2 | sitka
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | cap malheureux
# Processing Record 9 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | bubaque
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | crossville
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | san quintin
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | north bend
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | hasaki
# Processing Record 30 of Set 2 | camalu
# Processing Record 31 of Set 2 | kodinsk
# Processing Record 32 of Set 2 | yumen
# Processing Record 33 of Set 2 | charters towers
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | neyshabur
# Processing Record 36 of Set 2 | chapadinha
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | sisak
# Processing Record 42 of Set 2 | umea
# Processing Record 43 of Set 2 | vardo
# Processing Record 44 of Set 2 | high level
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | deputatskiy
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | neiva
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | merauke
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | savelugu
# Processing Record 5 of Set 3 | namtsy
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | hokitika
# Processing Record 8 of Set 3 | hutchinson
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | xining
# Processing Record 11 of Set 3 | tiznit
# Processing Record 12 of Set 3 | igarka
# Processing Record 13 of Set 3 | silifke
# Processing Record 14 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 3 | bairiki
# Processing Record 16 of Set 3 | makakilo city
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | chimbote
# Processing Record 19 of Set 3 | buala
# Processing Record 20 of Set 3 | guthrie
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | bauchi
# Processing Record 24 of Set 3 | nome
# Processing Record 25 of Set 3 | mataura
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | ambanja
# Processing Record 29 of Set 3 | ahipara
# Processing Record 30 of Set 3 | riyadh
# Processing Record 31 of Set 3 | karasuk
# Processing Record 32 of Set 3 | batsfjord
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | owando
# Processing Record 35 of Set 3 | kysyl-syr
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | dryden
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | puerto del rosario
# Processing Record 41 of Set 3 | macas
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | nehe
# Processing Record 44 of Set 3 | manama
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | waingapu
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | acarau
# Processing Record 50 of Set 3 | nim ka thana
# City not found. Skipping...
# Processing Record 1 of Set 4 | baoshan
# Processing Record 2 of Set 4 | nurota
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | cairns
# Processing Record 5 of Set 4 | russell
# Processing Record 6 of Set 4 | paamiut
# Processing Record 7 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 4 | kaeo
# Processing Record 9 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 4 | nemuro
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 4 | vila velha
# Processing Record 14 of Set 4 | hami
# Processing Record 15 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | lasa
# Processing Record 18 of Set 4 | am timan
# Processing Record 19 of Set 4 | victoria falls
# Processing Record 20 of Set 4 | westport
# Processing Record 21 of Set 4 | husavik
# Processing Record 22 of Set 4 | bad doberan
# Processing Record 23 of Set 4 | winnemucca
# Processing Record 24 of Set 4 | antalaha
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | labytnangi
# Processing Record 27 of Set 4 | daye
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | talnakh
# Processing Record 30 of Set 4 | khandyga
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | moron
# Processing Record 33 of Set 4 | uvelskiy
# Processing Record 34 of Set 4 | sampit
# Processing Record 35 of Set 4 | ajaccio
# Processing Record 36 of Set 4 | pierre
# Processing Record 37 of Set 4 | saint-augustin
# Processing Record 38 of Set 4 | kencong
# Processing Record 39 of Set 4 | fujinomiya
# Processing Record 40 of Set 4 | necochea
# Processing Record 41 of Set 4 | hrastnik
# Processing Record 42 of Set 4 | nagato
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | masvingo
# Processing Record 46 of Set 4 | pavlivka
# Processing Record 47 of Set 4 | san jeronimo
# Processing Record 48 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 4 | moose factory
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | sao lourenco do sul
# Processing Record 2 of Set 5 | meulaboh
# Processing Record 3 of Set 5 | puerto leguizamo
# Processing Record 4 of Set 5 | jacareacanga
# Processing Record 5 of Set 5 | visby
# Processing Record 6 of Set 5 | talaya
# Processing Record 7 of Set 5 | altay
# Processing Record 8 of Set 5 | vieux fort
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 5 | hithadhoo
# Processing Record 12 of Set 5 | lashio
# Processing Record 13 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 5 | dombarovskiy
# Processing Record 15 of Set 5 | sinop
# Processing Record 16 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 5 | magnolia
# Processing Record 18 of Set 5 | san isidro
# Processing Record 19 of Set 5 | valcourt
# Processing Record 20 of Set 5 | northam
# Processing Record 21 of Set 5 | dicabisagan
# Processing Record 22 of Set 5 | matveyevka
# Processing Record 23 of Set 5 | bintulu
# Processing Record 24 of Set 5 | cabo san lucas
# Processing Record 25 of Set 5 | hervey bay
# Processing Record 26 of Set 5 | ouango
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | mathbaria
# Processing Record 29 of Set 5 | baykit
# Processing Record 30 of Set 5 | vanimo
# Processing Record 31 of Set 5 | akdepe
# Processing Record 32 of Set 5 | teguise
# Processing Record 33 of Set 5 | huarmey
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | namyslow
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | melo
# Processing Record 38 of Set 5 | westerland
# Processing Record 39 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | newnan
# Processing Record 42 of Set 5 | waslala
# Processing Record 43 of Set 5 | moerai
# Processing Record 44 of Set 5 | porteirinha
# Processing Record 45 of Set 5 | batticaloa
# Processing Record 46 of Set 5 | santa cruz de tenerife
# Processing Record 47 of Set 5 | brejo santo
# Processing Record 48 of Set 5 | milove
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 50 of Set 5 | hamilton
# Processing Record 1 of Set 6 | lethem
# Processing Record 2 of Set 6 | roald
# Processing Record 3 of Set 6 | mandalgovi
# Processing Record 4 of Set 6 | san miguel
# Processing Record 5 of Set 6 | gidole
# Processing Record 6 of Set 6 | sosnovka
# Processing Record 7 of Set 6 | bull savanna
# Processing Record 8 of Set 6 | liberal
# Processing Record 9 of Set 6 | east london
# Processing Record 10 of Set 6 | bengkulu
# Processing Record 11 of Set 6 | mahajanga
# Processing Record 12 of Set 6 | berlevag
# Processing Record 13 of Set 6 | carballo
# Processing Record 14 of Set 6 | playa vicente
# Processing Record 15 of Set 6 | taft
# Processing Record 16 of Set 6 | chapais
# Processing Record 17 of Set 6 | maldonado
# Processing Record 18 of Set 6 | maravatio
# Processing Record 19 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 6 | pechora
# Processing Record 21 of Set 6 | langres
# Processing Record 22 of Set 6 | bima
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | kailua
# Processing Record 25 of Set 6 | nalut
# Processing Record 26 of Set 6 | lalmohan
# Processing Record 27 of Set 6 | samarai
# Processing Record 28 of Set 6 | santiago del estero
# Processing Record 29 of Set 6 | camacha
# Processing Record 30 of Set 6 | arlit
# Processing Record 31 of Set 6 | belyy yar
# Processing Record 32 of Set 6 | houma
# Processing Record 33 of Set 6 | aykhal
# Processing Record 34 of Set 6 | letlhakeng
# Processing Record 35 of Set 6 | panguna
# Processing Record 36 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 6 | yenagoa
# Processing Record 38 of Set 6 | kozachi laheri
# Processing Record 39 of Set 6 | havoysund
# Processing Record 40 of Set 6 | ailigandi
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | saint-louis
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | anadyr
# Processing Record 45 of Set 6 | kirakira
# Processing Record 46 of Set 6 | hirara
# Processing Record 47 of Set 6 | chuy
# Processing Record 48 of Set 6 | adre
# Processing Record 49 of Set 6 | labuan
# Processing Record 50 of Set 6 | berga
# Processing Record 1 of Set 7 | tartus
# Processing Record 2 of Set 7 | beinamar
# Processing Record 3 of Set 7 | alice
# Processing Record 4 of Set 7 | cockburn town
# Processing Record 5 of Set 7 | katobu
# Processing Record 6 of Set 7 | skjervoy
# Processing Record 7 of Set 7 | ulyanovo
# City not found. Skipping...
# Processing Record 8 of Set 7 | houston
# Processing Record 9 of Set 7 | alofi
# Processing Record 10 of Set 7 | litovko
# Processing Record 11 of Set 7 | bonthe
# Processing Record 12 of Set 7 | klaksvik
# Processing Record 13 of Set 7 | marshall
# Processing Record 14 of Set 7 | ginda
# Processing Record 15 of Set 7 | novyy urengoy
# Processing Record 16 of Set 7 | grindavik
# Processing Record 17 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | bon accord
# Processing Record 20 of Set 7 | mangrol
# Processing Record 21 of Set 7 | conde
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | stillwater
# Processing Record 24 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 7 | la asuncion
# Processing Record 27 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 28 of Set 7 | kikwit
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | catalina
# Processing Record 31 of Set 7 | karpathos
# Processing Record 32 of Set 7 | visnes
# Processing Record 33 of Set 7 | nanortalik
# Processing Record 34 of Set 7 | henties bay
# Processing Record 35 of Set 7 | iskele
# Processing Record 36 of Set 7 | shkotovo
# Processing Record 37 of Set 7 | tigil
# Processing Record 38 of Set 7 | oga
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | sumbe
# Processing Record 42 of Set 7 | mazulskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | sarandi
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | svetlogorsk
# Processing Record 46 of Set 7 | beringovskiy
# Processing Record 47 of Set 7 | huaihua
# Processing Record 48 of Set 7 | ati
# Processing Record 49 of Set 7 | taoudenni
# Processing Record 50 of Set 7 | sabang
# Processing Record 1 of Set 8 | harrisonburg
# Processing Record 2 of Set 8 | anta
# Processing Record 3 of Set 8 | vestmanna
# Processing Record 4 of Set 8 | linqiong
# Processing Record 5 of Set 8 | emerald
# Processing Record 6 of Set 8 | port-gentil
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | mastung
# Processing Record 9 of Set 8 | ternate
# Processing Record 10 of Set 8 | manta
# Processing Record 11 of Set 8 | avera
# Processing Record 12 of Set 8 | rudbar
# Processing Record 13 of Set 8 | monrovia
# Processing Record 14 of Set 8 | port hedland
# Processing Record 15 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 8 | keti bandar
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | gisborne
# Processing Record 19 of Set 8 | trinidad
# Processing Record 20 of Set 8 | gberia fotombu
# Processing Record 21 of Set 8 | gilgit
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | derzhavinsk
# Processing Record 24 of Set 8 | poya
# Processing Record 25 of Set 8 | gimli
# Processing Record 26 of Set 8 | serenje
# Processing Record 27 of Set 8 | aripuana
# Processing Record 28 of Set 8 | nuuk
# Processing Record 29 of Set 8 | akureyri
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | narsimhapur
# Processing Record 32 of Set 8 | namibe
# Processing Record 33 of Set 8 | yashalta
# Processing Record 34 of Set 8 | amapa
# Processing Record 35 of Set 8 | vylkove
# Processing Record 36 of Set 8 | alizai
# Processing Record 37 of Set 8 | dunedin
# Processing Record 38 of Set 8 | yaan
# Processing Record 39 of Set 8 | edelira
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | neuquen
# Processing Record 42 of Set 8 | talcahuano
# Processing Record 43 of Set 8 | rawson
# Processing Record 44 of Set 8 | aksu
# Processing Record 45 of Set 8 | osa
# Processing Record 46 of Set 8 | athabasca
# Processing Record 47 of Set 8 | hay river
# Processing Record 48 of Set 8 | harrisburg
# Processing Record 49 of Set 8 | notre-dame-du-lac
# Processing Record 50 of Set 8 | sisimiut
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 2 of Set 9 | los llanos de aridane
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | dhanera
# Processing Record 5 of Set 9 | kamphaeng phet
# Processing Record 6 of Set 9 | green valley
# Processing Record 7 of Set 9 | chufarovo
# Processing Record 8 of Set 9 | bilibino
# Processing Record 9 of Set 9 | gamba
# Processing Record 10 of Set 9 | oranjemund
# Processing Record 11 of Set 9 | lac du bonnet
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | mizdah
# Processing Record 14 of Set 9 | marawi
# Processing Record 15 of Set 9 | lawton
# Processing Record 16 of Set 9 | kamir
# Processing Record 17 of Set 9 | nassau
# Processing Record 18 of Set 9 | fare
# Processing Record 19 of Set 9 | gao
# Processing Record 20 of Set 9 | jalu
# Processing Record 21 of Set 9 | prince rupert
# Processing Record 22 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 9 | polson
# Processing Record 24 of Set 9 | guanay
# Processing Record 25 of Set 9 | patea
# Processing Record 26 of Set 9 | shenjiamen
# Processing Record 27 of Set 9 | tilichiki
# Processing Record 28 of Set 9 | rudnogorsk
# Processing Record 29 of Set 9 | kurilsk
# Processing Record 30 of Set 9 | mnogovershinnyy
# Processing Record 31 of Set 9 | jacksonville
# Processing Record 32 of Set 9 | shimoni
# Processing Record 33 of Set 9 | shirvan
# Processing Record 34 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 9 | namatanai
# Processing Record 36 of Set 9 | khirkiya
# Processing Record 37 of Set 9 | vao
# Processing Record 38 of Set 9 | warri
# Processing Record 39 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 9 | alyangula
# Processing Record 41 of Set 9 | port blair
# Processing Record 42 of Set 9 | vila franca do campo
# Processing Record 43 of Set 9 | okitipupa
# Processing Record 44 of Set 9 | golden
# Processing Record 45 of Set 9 | shahdadkot
# Processing Record 46 of Set 9 | krasnokamensk
# Processing Record 47 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 9 | padang
# Processing Record 49 of Set 9 | kodiak
# Processing Record 50 of Set 9 | sakakah
# Processing Record 1 of Set 10 | mayor pablo lagerenza
# Processing Record 2 of Set 10 | iqaluit
# Processing Record 3 of Set 10 | bitung
# Processing Record 4 of Set 10 | ust-maya
# Processing Record 5 of Set 10 | diu
# Processing Record 6 of Set 10 | bassano
# Processing Record 7 of Set 10 | san luis
# Processing Record 8 of Set 10 | port hardy
# Processing Record 9 of Set 10 | flinders
# Processing Record 10 of Set 10 | mayo
# Processing Record 11 of Set 10 | antofagasta
# Processing Record 12 of Set 10 | borama
# City not found. Skipping...
# Processing Record 13 of Set 10 | tazovskiy
# Processing Record 14 of Set 10 | cidreira
# Processing Record 15 of Set 10 | kidal
# Processing Record 16 of Set 10 | cap-aux-meules
# Processing Record 17 of Set 10 | arenapolis
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 20 of Set 10 | tromso
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | yetholm
# City not found. Skipping...
# Processing Record 23 of Set 10 | morondava
# Processing Record 24 of Set 10 | saint-paul
# Processing Record 25 of Set 10 | pinega
# Processing Record 26 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 27 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 10 | morehead
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | asau
# Processing Record 32 of Set 10 | torres
# Processing Record 33 of Set 10 | camapua
# Processing Record 34 of Set 10 | leningradskiy
# Processing Record 35 of Set 10 | takoradi
# Processing Record 36 of Set 10 | narsaq
# Processing Record 37 of Set 10 | warah
# Processing Record 38 of Set 10 | marsh harbour
# Processing Record 39 of Set 10 | simao
# Processing Record 40 of Set 10 | sao felix do xingu
# Processing Record 41 of Set 10 | rakhya
# City not found. Skipping...
# Processing Record 42 of Set 10 | woodward
# Processing Record 43 of Set 10 | binga
# Processing Record 44 of Set 10 | tahta
# Processing Record 45 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 10 | besikduzu
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | tucurui
# Processing Record 49 of Set 10 | tulsipur
# Processing Record 50 of Set 10 | nortelandia
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | katherine
# Processing Record 3 of Set 11 | lompoc
# Processing Record 4 of Set 11 | sawtell
# Processing Record 5 of Set 11 | daokou
# Processing Record 6 of Set 11 | green river
# Processing Record 7 of Set 11 | dubbo
# Processing Record 8 of Set 11 | palana
# Processing Record 9 of Set 11 | brae
# Processing Record 10 of Set 11 | constantine
# Processing Record 11 of Set 11 | srinagar
# Processing Record 12 of Set 11 | nilagiri
# Processing Record 13 of Set 11 | natal
# Processing Record 14 of Set 11 | muros
# Processing Record 15 of Set 11 | marovoay
# Processing Record 16 of Set 11 | muli
# Processing Record 17 of Set 11 | calama
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | tautira
# Processing Record 20 of Set 11 | sinnamary
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | troitskoye
# Processing Record 23 of Set 11 | la ronge
# Processing Record 24 of Set 11 | uwajima
# Processing Record 25 of Set 11 | chiang rai
# Processing Record 26 of Set 11 | soavinandriana
# Processing Record 27 of Set 11 | kavaratti
# Processing Record 28 of Set 11 | sobolevo
# Processing Record 29 of Set 11 | teguldet
# Processing Record 30 of Set 11 | bereda
# Processing Record 31 of Set 11 | namalenga
# Processing Record 32 of Set 11 | bourail
# Processing Record 33 of Set 11 | tucuma
# Processing Record 34 of Set 11 | pathein
# Processing Record 35 of Set 11 | lazarev
# Processing Record 36 of Set 11 | boende
# Processing Record 37 of Set 11 | grand gaube
# Processing Record 38 of Set 11 | san patricio
# Processing Record 39 of Set 11 | lubao
# Processing Record 40 of Set 11 | taltal
# Processing Record 41 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 42 of Set 11 | ulaangom
# Processing Record 43 of Set 11 | bandar-e lengeh
# Processing Record 44 of Set 11 | bawku
# Processing Record 45 of Set 11 | granadilla de abona
# Processing Record 46 of Set 11 | mecca
# Processing Record 47 of Set 11 | saint-joseph
# Processing Record 48 of Set 11 | bamiantong
# Processing Record 49 of Set 11 | hudson bay
# Processing Record 50 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 1 of Set 12 | pombas
# Processing Record 2 of Set 12 | baherden
# Processing Record 3 of Set 12 | amazar
# Processing Record 4 of Set 12 | kuytun
# Processing Record 5 of Set 12 | kiama
# Processing Record 6 of Set 12 | madang
# Processing Record 7 of Set 12 | mehamn
# Processing Record 8 of Set 12 | aklavik
# Processing Record 9 of Set 12 | karaton
# Processing Record 10 of Set 12 | guozhen
# Processing Record 11 of Set 12 | bilma
# Processing Record 12 of Set 12 | toowoomba
# Processing Record 13 of Set 12 | iwanai
# Processing Record 14 of Set 12 | gobabis
# Processing Record 15 of Set 12 | havre-saint-pierre
# Processing Record 16 of Set 12 | apen
# Processing Record 17 of Set 12 | roseburg
# Processing Record 18 of Set 12 | seoul
# Processing Record 19 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 12 | soyo
# Processing Record 22 of Set 12 | inhambane
# Processing Record 23 of Set 12 | hovd
# Processing Record 24 of Set 12 | dongsheng
# Processing Record 25 of Set 12 | rafaela
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | senneterre
# Processing Record 28 of Set 12 | koundara
# Processing Record 29 of Set 12 | shelburne
# Processing Record 30 of Set 12 | rio branco
# Processing Record 31 of Set 12 | sao joao da barra
# Processing Record 32 of Set 12 | inirida
# Processing Record 33 of Set 12 | namie
# Processing Record 34 of Set 12 | el alto
# Processing Record 35 of Set 12 | bouna
# Processing Record 36 of Set 12 | san pedro
# Processing Record 37 of Set 12 | grand-santi
# Processing Record 38 of Set 12 | keetmanshoop
# Processing Record 39 of Set 12 | wucheng
# Processing Record 40 of Set 12 | calamar
# Processing Record 41 of Set 12 | tarko-sale
# Processing Record 42 of Set 12 | bhiwani
# Processing Record 43 of Set 12 | alattyan
# Processing Record 44 of Set 12 | omboue
# Processing Record 45 of Set 12 | chardara
# Processing Record 46 of Set 12 | fenoarivo atsinanana
# Processing Record 47 of Set 12 | bocholt
# Processing Record 48 of Set 12 | mahibadhoo
# Processing Record 49 of Set 12 | sorong
# Processing Record 50 of Set 12 | kemijarvi
# Processing Record 1 of Set 13 | lavrentiya
# Processing Record 2 of Set 13 | bayeux
# Processing Record 3 of Set 13 | buin
# Processing Record 4 of Set 13 | hambantota
# Processing Record 5 of Set 13 | jiuquan
# Processing Record 6 of Set 13 | zhanaozen
# Processing Record 7 of Set 13 | malanje
# Processing Record 8 of Set 13 | vista hermosa
# Processing Record 9 of Set 13 | tepalcatepec
# Processing Record 10 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 11 of Set 13 | guerrero negro
# Processing Record 12 of Set 13 | lazaro cardenas
# Processing Record 13 of Set 13 | davila
# Processing Record 14 of Set 13 | yuksekova
# Processing Record 15 of Set 13 | basco
# Processing Record 16 of Set 13 | puerto escondido
# Processing Record 17 of Set 13 | surt
# Processing Record 18 of Set 13 | hobyo
# Processing Record 19 of Set 13 | iacu
# Processing Record 20 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 13 | mishelevka
# Processing Record 22 of Set 13 | korgen
# Processing Record 23 of Set 13 | adrar
# Processing Record 24 of Set 13 | sonoita
# Processing Record 25 of Set 13 | fukue
# Processing Record 26 of Set 13 | krapivinskiy
# Processing Record 27 of Set 13 | nkowakowa
# Processing Record 28 of Set 13 | ales
# Processing Record 29 of Set 13 | nioro
# Processing Record 30 of Set 13 | vestmannaeyjar
# Processing Record 31 of Set 13 | zeya
# Processing Record 32 of Set 13 | kholtoson
# Processing Record 33 of Set 13 | sangmelima
# Processing Record 34 of Set 13 | leshan
# Processing Record 35 of Set 13 | denizli
# Processing Record 36 of Set 13 | yerbogachen
# Processing Record 37 of Set 13 | kaka
# Processing Record 38 of Set 13 | nesbyen
# Processing Record 39 of Set 13 | opunake
# Processing Record 40 of Set 13 | homer
# Processing Record 41 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 13 | calabozo
# Processing Record 43 of Set 13 | ziarat
# Processing Record 44 of Set 13 | okha
# Processing Record 45 of Set 13 | cayenne
# Processing Record 46 of Set 13 | ramjibanpur
# Processing Record 47 of Set 13 | san pedro de ycuamandiyu
# Processing Record 48 of Set 13 | gizo
# Processing Record 49 of Set 13 | vuktyl
# Processing Record 50 of Set 13 | tual
# Processing Record 1 of Set 14 | cape canaveral
# Processing Record 2 of Set 14 | kalmunai
# Processing Record 3 of Set 14 | manoel urbano
# Processing Record 4 of Set 14 | praia da vitoria
# Processing Record 5 of Set 14 | guanica
# Processing Record 6 of Set 14 | rassvet
# Processing Record 7 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 14 | harper
# Processing Record 9 of Set 14 | vallenar
# Processing Record 10 of Set 14 | jiazi
# Processing Record 11 of Set 14 | chibuto
# Processing Record 12 of Set 14 | belle fourche
# Processing Record 13 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 14 | narasannapeta
# Processing Record 15 of Set 14 | nabire
# Processing Record 16 of Set 14 | baykalovo
# Processing Record 17 of Set 14 | honningsvag
# Processing Record 18 of Set 14 | lexington
# Processing Record 19 of Set 14 | port-cartier
# Processing Record 20 of Set 14 | wuwei
# Processing Record 21 of Set 14 | taquarituba
# Processing Record 22 of Set 14 | jardim
# Processing Record 23 of Set 14 | tabuk
# Processing Record 24 of Set 14 | kupang
# Processing Record 25 of Set 14 | estevan
# Processing Record 26 of Set 14 | mirabad
# Processing Record 27 of Set 14 | trincomalee
# Processing Record 28 of Set 14 | slonim
# Processing Record 29 of Set 14 | stolin
# Processing Record 30 of Set 14 | koberice
# Processing Record 31 of Set 14 | axim
# Processing Record 32 of Set 14 | martapura
# Processing Record 33 of Set 14 | coahuayana
# Processing Record 34 of Set 14 | guangyuan
# Processing Record 35 of Set 14 | cabedelo
# Processing Record 36 of Set 14 | rondonopolis
# Processing Record 37 of Set 14 | otradnoye
# Processing Record 38 of Set 14 | clyde river
# Processing Record 39 of Set 14 | cuamba
# Processing Record 40 of Set 14 | luanda
# Processing Record 41 of Set 14 | mbini
# Processing Record 42 of Set 14 | mikuni
# Processing Record 43 of Set 14 | tuensang
# Processing Record 44 of Set 14 | makhinjauri
# Processing Record 45 of Set 14 | bobrov
# Processing Record 46 of Set 14 | sattahip
# Processing Record 47 of Set 14 | sosua
# Processing Record 48 of Set 14 | kutum
# Processing Record 49 of Set 14 | krasnoselkup
# Processing Record 50 of Set 14 | kaifeng
# Processing Record 1 of Set 15 | yeniseysk
# Processing Record 2 of Set 15 | djenne
# Processing Record 3 of Set 15 | tomatlan
# Processing Record 4 of Set 15 | dieppe bay
# City not found. Skipping...
# Processing Record 5 of Set 15 | ibotirama
# Processing Record 6 of Set 15 | conceicao da barra
# Processing Record 7 of Set 15 | toamasina
# Processing Record 8 of Set 15 | newport
# Processing Record 9 of Set 15 | amahai
# Processing Record 10 of Set 15 | xuddur
# Processing Record 11 of Set 15 | san julian
# Processing Record 12 of Set 15 | haines junction
# Processing Record 13 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 15 | manyana
# Processing Record 16 of Set 15 | novo aripuana
# Processing Record 17 of Set 15 | celestun
# Processing Record 18 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 15 | abu dhabi
# Processing Record 20 of Set 15 | menongue
# Processing Record 21 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 15 | matagami
# Processing Record 23 of Set 15 | nizhniy odes
# Processing Record 24 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 25 of Set 15 | uige
# Processing Record 26 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 27 of Set 15 | kautokeino
# Processing Record 28 of Set 15 | ruteng
# Processing Record 29 of Set 15 | sovetskiy
# Processing Record 30 of Set 15 | tommot
# Processing Record 31 of Set 15 | sorkjosen
# Processing Record 32 of Set 15 | kihei
# Processing Record 33 of Set 15 | rio gallegos
# Processing Record 34 of Set 15 | lodwar
# Processing Record 35 of Set 15 | khandbari
# Processing Record 36 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 15 | palaikastron
# Processing Record 38 of Set 15 | martinsburg
# Processing Record 39 of Set 15 | preobrazheniye
# Processing Record 40 of Set 15 | norrtalje
# Processing Record 41 of Set 15 | socorro
# Processing Record 42 of Set 15 | cumaribo
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Create a DataFrame of the city weather data. 
# Convert the array of dictionaries to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kapaa  22.0752 -159.3190     82.38        77         100       20.71
# 1      La Cruz  23.9167 -106.9000     65.80        86           9        0.78
# 2     Acapulco  16.8634  -99.8901     75.02        83           0        6.91
# 3   Butaritari   3.0707  172.7902     81.52        74          99       11.65
# 4         Tafo   6.7345   -1.6127     71.58        88         100        2.98
# 5  Pundaguitan   6.3711  126.1689     81.93        76         100        4.70
# 6  Port Alfred -33.5906   26.8910     63.18        90          50        1.99
# 7  Porterville  36.0652 -119.0168     71.02        40           0        0.00
# 8    Saskylakh  71.9167  114.0833     -2.00        94         100       12.03
# 9      Rikitea -23.1203 -134.9692     77.99        63         100        9.55
#
#   Current Description Country                 Date
# 0     overcast clouds      US  2022-04-04 03:06:09
# 1           clear sky      MX  2022-04-04 03:06:10
# 2           clear sky      MX  2022-04-04 03:06:10
# 3     overcast clouds      KI  2022-04-04 03:06:10
# 4     overcast clouds      GH  2022-04-04 03:06:11
# 5     overcast clouds      PH  2022-04-04 03:06:12
# 6    scattered clouds      ZA  2022-04-04 03:06:12
# 7           clear sky      US  2022-04-04 03:06:05
# 8     overcast clouds      RU  2022-04-04 03:06:13
# 9     overcast clouds      PF  2022-04-04 03:00:37

# %%
# Reorder the columns in the DataFrame. 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kapaa      US  22.0752 -159.3190     82.38        77         100
# 1      La Cruz      MX  23.9167 -106.9000     65.80        86           9
# 2     Acapulco      MX  16.8634  -99.8901     75.02        83           0
# 3   Butaritari      KI   3.0707  172.7902     81.52        74          99
# 4         Tafo      GH   6.7345   -1.6127     71.58        88         100
# 5  Pundaguitan      PH   6.3711  126.1689     81.93        76         100
# 6  Port Alfred      ZA -33.5906   26.8910     63.18        90          50
# 7  Porterville      US  36.0652 -119.0168     71.02        40           0
# 8    Saskylakh      RU  71.9167  114.0833     -2.00        94         100
# 9      Rikitea      PF -23.1203 -134.9692     77.99        63         100
#
#    Wind Speed Current Description
# 0       20.71     overcast clouds
# 1        0.78           clear sky
# 2        6.91           clear sky
# 3       11.65     overcast clouds
# 4        2.98     overcast clouds
# 5        4.70     overcast clouds
# 6        1.99    scattered clouds
# 7        0.00           clear sky
# 8       12.03     overcast clouds
# 9        9.55     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Database/WeatherPy_Database.csv"
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file)
