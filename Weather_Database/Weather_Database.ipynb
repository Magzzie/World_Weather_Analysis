# %%
# Import the dependencies. 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations. 
# 2000 did not real any hotel results for vacation search, so we increased the cities search limits.
lats = np.random.uniform(low=-90.000, high=90.000, size=10000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=10000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 10000

# %%
# Import citipy module. 
from citipy import citipy

# %%
# Create a list for holding the cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination. 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count. 
len(cities)
# Out:
# 2203

# %%
print(cities)
# Out:
# ['kapaa', 'katsuura', 'jamestown', 'shache', 'bredasdorp', 'taolanaro', 'kaitangata', 'oranjemund', 'paamiut', 'bluff', 'providencia', 'faanui', 'zbarazh', 'arraial do cabo', 'labuhan', 'saraland', 'hobart', 'lompoc', 'ribeira grande', 'kismayo', 'constitucion', 'ushuaia', 'labutta', 'santa cruz cabralia', 'cape town', 'albany', 'halalo', 'alofi', 'palmer', 'lafiagi', 'sinnamary', 'chuy', 'atuona', 'karamay', 'castro', 'lazaro cardenas', 'rikitea', 'rochester', 'kodiak', 'vaini', 'mataura', 'mys shmidta', 'mahebourg', 'san cristobal', 'hilo', 'barentsburg', 'komsomolskiy', 'punta arenas', 'narsaq', 'hami', 'tuktoyaktuk', 'hualmay', 'avarua', 'yulara', 'iqaluit', 'kailua', 'chokurdakh', 'havre', 'barrow', 'airai', 'tilichiki', 'sambava', 'olafsvik', 'zachagansk', 'touros', 'attawapiskat', 'butaritari', 'torbay', 'belushya guba', 'kazalinsk', 'puerto ayora', 'busselton', 'satitoa', 'hermanus', 'lakshettipet', 'baturaja', 'sentyabrskiy', 'san patricio', 'tokuyama', 'poykovskiy', 'mogoytuy', 'port alfred', 'praia', 'east london', 'carnarvon', 'lebu', 'thompson', 'taikang', 'kloulklubed', 'isangel', 'agadez', 'hithadhoo', 'la ronge', 'batticaloa', 'pisco', 'lagoa', 'diffa', 'pouebo', 'codrington', 'yellowknife', 'boa vista', 'tuatapere', 'porto velho', 'amderma', 'hambantota', 'padang', 'inhambane', 'sarangani', 'comodoro rivadavia', 'tahoua', 'sayhat', 'sawakin', 'balikpapan', 'cherskiy', 'luderitz', 'acapulco', 'pital', 'alyangula', 'lata', 'provideniya', 'curup', 'namibe', 'maniitsoq', 'nanortalik', 'okha', 'dzhusaly', 'soria', 'upernavik', 'omboue', 'garm', 'kurchum', 'beringovskiy', 'puerto del rosario', 'pevek', 'grindavik', 'saint anthony', 'guaruja', 'lokachi', 'excelsior springs', 'fort nelson', 'mersing', 'axams', 'kuche', 'severo-kurilsk', 'dorogobuzh', 'kruisfontein', 'clyde river', 'tasiilaq', 'uyuni', 'guanica', 'marang', 'nkhotakota', 'bolungarvik', 'new norfolk', 'dukat', 'yanam', 'kirakira', 'northam', 'mount isa', 'taltal', 'dikson', 'nizhniy kuranakh', 'norman wells', 'novikovo', 'salalah', 'the valley', 'jalu', 'yaan', 'minab', 'havre-saint-pierre', 'gusinoye ozero', 'sao joao da barra', 'paradwip', 'artyk', 'ocos', 'dolbeau', 'nhulunbuy', 'nishihara', 'saint-philippe', 'margate', 'souillac', 'fortuna', 'imbituba', 'fairbanks', 'saskylakh', 'talnakh', 'temaraia', 'klaksvik', 'doctor pedro p. pena', 'nikolskoye', 'cockburn town', 'ornskoldsvik', 'tiksi', 'bilibino', 'natal', 'verkh-suetka', 'mar del plata', 'mahonda', 'boppard', 'geraldton', 'sorong', 'ancud', 'tsihombe', 'grand-santi', 'ponta delgada', 'longyearbyen', 'illoqqortoormiut', 'kyzyl-suu', 'nipawin', 'guerrero negro', 'sao felix do xingu', 'saint george', 'coquimbo', 'ojinaga', 'abu dhabi', 'leningradskiy', 'bengkulu', 'san policarpo', 'carolina', 'caravelas', 'lavrentiya', 'macaubas', 'nome', 'kamenskoye', 'aklavik', 'brae', 'ngukurr', 'cabo san lucas', 'dingle', 'yuncheng', 'lolua', 'blagodatnoye', 'umzimvubu', 'rangapara', 'toliary', 'lahaina', 'jacareacanga', 'litoral del san juan', 'khandyga', 'waipawa', 'karaul', 'barinas', 'manaure', 'bolton', 'cacoal', 'brooks', 'markova', 'pizarro', 'fukue', 'berikulskiy', 'jumla', 'vytegra', 'dunedin', 'marcona', 'yining', 'batagay-alyta', 'fagernes', 'nouadhibou', 'salvador', 'kashan', 'devyatka', 'khatanga', 'atar', 'matane', 'roald', 'halmstad', 'liverpool', 'maraa', 'narsipatnam', 'burica', 'alice springs', 'tabuk', 'fez', 'grand gaube', 'cayenne', 'hasaki', 'hervey bay', 'ilhabela', 'hamilton', 'salto', 'antalaha', 'bethel', 'naze', 'ixtapa', 'nuuk', 'darbhanga', 'scarborough', 'nyaunglebin', 'ilulissat', 'antiguo morelos', 'niquelandia', 'namatanai', 'laguna', 'qui nhon', 'nizhneyansk', 'hastings', 'sola', 'bassano', 'georgetown', 'grand centre', 'ternate', 'podor', 'nizhniy tsasuchey', 'lasa', 'kavaratti', 'ndjole', 'khash', 'pangnirtung', 'suslovo', 'rungata', 'togur', 'barra patuca', 'hongjiang', 'artigas', 'valparaiso', 'bandundu', 'vaitupu', 'karratha', 'chagda', 'haapu', 'mlonggo', 'khani', 'taou ...

# %%
# Import dependencies.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library. 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters. 
record_count = 1 
set_count = 1

# Loop through all the cities in our list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1
    
    # Run an API request for each of the cities. 
    try: 
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description= city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard. 
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description,
                         "Country": city_country,
                         "Date": city_date})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete. 
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | shache
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | oranjemund
# Processing Record 9 of Set 1 | paamiut
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | providencia
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | zbarazh
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | labuhan
# Processing Record 16 of Set 1 | saraland
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | lompoc
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | kismayo
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 1 | santa cruz cabralia
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | palmer
# Processing Record 30 of Set 1 | lafiagi
# Processing Record 31 of Set 1 | sinnamary
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | lazaro cardenas
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | rochester
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | komsomolskiy
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | hami
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | hualmay
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | yulara
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | kailua
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | havre
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | tilichiki
# Processing Record 12 of Set 2 | sambava
# Processing Record 13 of Set 2 | olafsvik
# Processing Record 14 of Set 2 | zachagansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | lakshettipet
# Processing Record 26 of Set 2 | baturaja
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | tokuyama
# Processing Record 30 of Set 2 | poykovskiy
# Processing Record 31 of Set 2 | mogoytuy
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | praia
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | taikang
# Processing Record 39 of Set 2 | kloulklubed
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | agadez
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | la ronge
# Processing Record 44 of Set 2 | batticaloa
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | lagoa
# Processing Record 47 of Set 2 | diffa
# Processing Record 48 of Set 2 | pouebo
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | boa vista
# Processing Record 2 of Set 3 | tuatapere
# Processing Record 3 of Set 3 | porto velho
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | hambantota
# Processing Record 6 of Set 3 | padang
# Processing Record 7 of Set 3 | inhambane
# Processing Record 8 of Set 3 | sarangani
# Processing Record 9 of Set 3 | comodoro rivadavia
# Processing Record 10 of Set 3 | tahoua
# Processing Record 11 of Set 3 | sayhat
# Processing Record 12 of Set 3 | sawakin
# Processing Record 13 of Set 3 | balikpapan
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | acapulco
# Processing Record 17 of Set 3 | pital
# Processing Record 18 of Set 3 | alyangula
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | curup
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | maniitsoq
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | okha
# Processing Record 26 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 3 | soria
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | omboue
# Processing Record 30 of Set 3 | garm
# City not found. Skipping...
# Processing Record 31 of Set 3 | kurchum
# Processing Record 32 of Set 3 | beringovskiy
# Processing Record 33 of Set 3 | puerto del rosario
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | guaruja
# Processing Record 38 of Set 3 | lokachi
# Processing Record 39 of Set 3 | excelsior springs
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | mersing
# Processing Record 42 of Set 3 | axams
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | dorogobuzh
# Processing Record 46 of Set 3 | kruisfontein
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | uyuni
# Processing Record 50 of Set 3 | guanica
# Processing Record 1 of Set 4 | marang
# Processing Record 2 of Set 4 | nkhotakota
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | dukat
# Processing Record 6 of Set 4 | yanam
# Processing Record 7 of Set 4 | kirakira
# Processing Record 8 of Set 4 | northam
# Processing Record 9 of Set 4 | mount isa
# Processing Record 10 of Set 4 | taltal
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | nizhniy kuranakh
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | novikovo
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | the valley
# Processing Record 17 of Set 4 | jalu
# Processing Record 18 of Set 4 | yaan
# Processing Record 19 of Set 4 | minab
# Processing Record 20 of Set 4 | havre-saint-pierre
# Processing Record 21 of Set 4 | gusinoye ozero
# Processing Record 22 of Set 4 | sao joao da barra
# Processing Record 23 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 4 | ocos
# Processing Record 26 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 4 | nhulunbuy
# Processing Record 28 of Set 4 | nishihara
# Processing Record 29 of Set 4 | saint-philippe
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | fortuna
# Processing Record 33 of Set 4 | imbituba
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | saskylakh
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | ornskoldsvik
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | natal
# Processing Record 46 of Set 4 | verkh-suetka
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | mahonda
# Processing Record 49 of Set 4 | boppard
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | sorong
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | grand-santi
# Processing Record 5 of Set 5 | ponta delgada
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | kyzyl-suu
# Processing Record 9 of Set 5 | nipawin
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | sao felix do xingu
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | ojinaga
# Processing Record 15 of Set 5 | abu dhabi
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | san policarpo
# Processing Record 19 of Set 5 | carolina
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | lavrentiya
# Processing Record 22 of Set 5 | macaubas
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | brae
# Processing Record 27 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | dingle
# Processing Record 30 of Set 5 | yuncheng
# Processing Record 31 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 5 | blagodatnoye
# Processing Record 33 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 5 | rangapara
# Processing Record 35 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 5 | lahaina
# Processing Record 37 of Set 5 | jacareacanga
# Processing Record 38 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 39 of Set 5 | khandyga
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 5 | barinas
# Processing Record 43 of Set 5 | manaure
# Processing Record 44 of Set 5 | bolton
# Processing Record 45 of Set 5 | cacoal
# Processing Record 46 of Set 5 | brooks
# Processing Record 47 of Set 5 | markova
# Processing Record 48 of Set 5 | pizarro
# Processing Record 49 of Set 5 | fukue
# Processing Record 50 of Set 5 | berikulskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | jumla
# Processing Record 2 of Set 6 | vytegra
# Processing Record 3 of Set 6 | dunedin
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | yining
# Processing Record 6 of Set 6 | batagay-alyta
# Processing Record 7 of Set 6 | fagernes
# Processing Record 8 of Set 6 | nouadhibou
# Processing Record 9 of Set 6 | salvador
# Processing Record 10 of Set 6 | kashan
# Processing Record 11 of Set 6 | devyatka
# City not found. Skipping...
# Processing Record 12 of Set 6 | khatanga
# Processing Record 13 of Set 6 | atar
# Processing Record 14 of Set 6 | matane
# Processing Record 15 of Set 6 | roald
# Processing Record 16 of Set 6 | halmstad
# Processing Record 17 of Set 6 | liverpool
# Processing Record 18 of Set 6 | maraa
# Processing Record 19 of Set 6 | narsipatnam
# Processing Record 20 of Set 6 | burica
# City not found. Skipping...
# Processing Record 21 of Set 6 | alice springs
# Processing Record 22 of Set 6 | tabuk
# Processing Record 23 of Set 6 | fez
# Processing Record 24 of Set 6 | grand gaube
# Processing Record 25 of Set 6 | cayenne
# Processing Record 26 of Set 6 | hasaki
# Processing Record 27 of Set 6 | hervey bay
# Processing Record 28 of Set 6 | ilhabela
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | salto
# Processing Record 31 of Set 6 | antalaha
# Processing Record 32 of Set 6 | bethel
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | ixtapa
# Processing Record 35 of Set 6 | nuuk
# Processing Record 36 of Set 6 | darbhanga
# Processing Record 37 of Set 6 | scarborough
# Processing Record 38 of Set 6 | nyaunglebin
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | antiguo morelos
# Processing Record 41 of Set 6 | niquelandia
# Processing Record 42 of Set 6 | namatanai
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | qui nhon
# Processing Record 45 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 6 | hastings
# Processing Record 47 of Set 6 | sola
# Processing Record 48 of Set 6 | bassano
# Processing Record 49 of Set 6 | georgetown
# Processing Record 50 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 7 | ternate
# Processing Record 2 of Set 7 | podor
# Processing Record 3 of Set 7 | nizhniy tsasuchey
# Processing Record 4 of Set 7 | lasa
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | ndjole
# Processing Record 7 of Set 7 | khash
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | suslovo
# Processing Record 10 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 7 | togur
# Processing Record 12 of Set 7 | barra patuca
# Processing Record 13 of Set 7 | hongjiang
# Processing Record 14 of Set 7 | artigas
# Processing Record 15 of Set 7 | valparaiso
# Processing Record 16 of Set 7 | bandundu
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 7 | haapu
# City not found. Skipping...
# Processing Record 21 of Set 7 | mlonggo
# Processing Record 22 of Set 7 | khani
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | sur
# Processing Record 25 of Set 7 | sabang
# Processing Record 26 of Set 7 | ambilobe
# Processing Record 27 of Set 7 | bandarbeyla
# Processing Record 28 of Set 7 | chernyshevskiy
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | kharitonovo
# Processing Record 31 of Set 7 | smithers
# Processing Record 32 of Set 7 | half moon bay
# Processing Record 33 of Set 7 | ponta do sol
# Processing Record 34 of Set 7 | asau
# Processing Record 35 of Set 7 | kampong cham
# Processing Record 36 of Set 7 | leshukonskoye
# Processing Record 37 of Set 7 | anloga
# Processing Record 38 of Set 7 | egvekinot
# Processing Record 39 of Set 7 | yenagoa
# Processing Record 40 of Set 7 | te anau
# Processing Record 41 of Set 7 | bayangol
# Processing Record 42 of Set 7 | manzhouli
# Processing Record 43 of Set 7 | billings
# Processing Record 44 of Set 7 | san juan evangelista
# Processing Record 45 of Set 7 | banda aceh
# Processing Record 46 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | meiringen
# Processing Record 49 of Set 7 | bourail
# Processing Record 50 of Set 7 | nelson bay
# Processing Record 1 of Set 8 | fare
# Processing Record 2 of Set 8 | warmbad
# Processing Record 3 of Set 8 | luanda
# Processing Record 4 of Set 8 | najran
# Processing Record 5 of Set 8 | zyryanka
# Processing Record 6 of Set 8 | srednekolymsk
# Processing Record 7 of Set 8 | muscat
# Processing Record 8 of Set 8 | gaoual
# Processing Record 9 of Set 8 | plyussa
# Processing Record 10 of Set 8 | port elizabeth
# Processing Record 11 of Set 8 | zhangjiakou
# Processing Record 12 of Set 8 | westport
# Processing Record 13 of Set 8 | ahipara
# Processing Record 14 of Set 8 | rio grande
# Processing Record 15 of Set 8 | celestun
# Processing Record 16 of Set 8 | dali
# Processing Record 17 of Set 8 | borogontsy
# Processing Record 18 of Set 8 | haines junction
# Processing Record 19 of Set 8 | vestmannaeyjar
# Processing Record 20 of Set 8 | karmana
# City not found. Skipping...
# Processing Record 21 of Set 8 | qaanaaq
# Processing Record 22 of Set 8 | puerto asis
# Processing Record 23 of Set 8 | concepcion
# Processing Record 24 of Set 8 | kukshi
# Processing Record 25 of Set 8 | gannan
# Processing Record 26 of Set 8 | itaituba
# Processing Record 27 of Set 8 | sayat
# Processing Record 28 of Set 8 | makakilo city
# Processing Record 29 of Set 8 | port hardy
# Processing Record 30 of Set 8 | ayan
# Processing Record 31 of Set 8 | seoul
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | bergen
# Processing Record 34 of Set 8 | beysehir
# Processing Record 35 of Set 8 | madimba
# Processing Record 36 of Set 8 | bahia de caraquez
# Processing Record 37 of Set 8 | leh
# Processing Record 38 of Set 8 | torres
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | kurilsk
# Processing Record 41 of Set 8 | gladstone
# Processing Record 42 of Set 8 | saint-joseph
# Processing Record 43 of Set 8 | siguiri
# Processing Record 44 of Set 8 | wagar
# Processing Record 45 of Set 8 | wanaka
# Processing Record 46 of Set 8 | los llanos de aridane
# Processing Record 47 of Set 8 | necochea
# Processing Record 48 of Set 8 | svetlogorsk
# Processing Record 49 of Set 8 | port-gentil
# Processing Record 50 of Set 8 | tautira
# Processing Record 1 of Set 9 | broome
# Processing Record 2 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 9 | nanning
# Processing Record 4 of Set 9 | townsville
# Processing Record 5 of Set 9 | vicuna
# Processing Record 6 of Set 9 | kuusankoski
# Processing Record 7 of Set 9 | haverfordwest
# Processing Record 8 of Set 9 | socorro
# Processing Record 9 of Set 9 | baft
# Processing Record 10 of Set 9 | pacific grove
# Processing Record 11 of Set 9 | erenhot
# Processing Record 12 of Set 9 | ugoofaaru
# Processing Record 13 of Set 9 | luancheng
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | aykhal
# Processing Record 16 of Set 9 | hibbing
# Processing Record 17 of Set 9 | banjar
# Processing Record 18 of Set 9 | impfondo
# Processing Record 19 of Set 9 | ouahigouya
# Processing Record 20 of Set 9 | olinda
# Processing Record 21 of Set 9 | thinadhoo
# Processing Record 22 of Set 9 | caxias
# Processing Record 23 of Set 9 | suluova
# Processing Record 24 of Set 9 | sakaiminato
# Processing Record 25 of Set 9 | whitehorse
# Processing Record 26 of Set 9 | loikaw
# Processing Record 27 of Set 9 | vao
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | san quintin
# Processing Record 30 of Set 9 | hokitika
# Processing Record 31 of Set 9 | bundaberg
# Processing Record 32 of Set 9 | tomatlan
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | druzhba
# Processing Record 35 of Set 9 | dumas
# Processing Record 36 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 9 | fraserburgh
# Processing Record 38 of Set 9 | maloy
# Processing Record 39 of Set 9 | ostrovnoy
# Processing Record 40 of Set 9 | pangai
# Processing Record 41 of Set 9 | totskoye
# Processing Record 42 of Set 9 | loei
# Processing Record 43 of Set 9 | bambous virieux
# Processing Record 44 of Set 9 | xai-xai
# Processing Record 45 of Set 9 | santa cruz
# Processing Record 46 of Set 9 | neyshabur
# Processing Record 47 of Set 9 | muleba
# Processing Record 48 of Set 9 | kamina
# Processing Record 49 of Set 9 | nago
# Processing Record 50 of Set 9 | husavik
# Processing Record 1 of Set 10 | srandakan
# Processing Record 2 of Set 10 | coihaique
# Processing Record 3 of Set 10 | olonets
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | shelburne
# Processing Record 6 of Set 10 | vozhd proletariata
# City not found. Skipping...
# Processing Record 7 of Set 10 | tatawin
# Processing Record 8 of Set 10 | badarwas
# Processing Record 9 of Set 10 | ocala
# Processing Record 10 of Set 10 | anaconda
# Processing Record 11 of Set 10 | otradnoye
# Processing Record 12 of Set 10 | morondava
# Processing Record 13 of Set 10 | varena
# Processing Record 14 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 15 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 10 | macamic
# Processing Record 17 of Set 10 | hofn
# Processing Record 18 of Set 10 | aitape
# Processing Record 19 of Set 10 | daru
# Processing Record 20 of Set 10 | cidreira
# Processing Record 21 of Set 10 | buloh kasap
# Processing Record 22 of Set 10 | sayansk
# Processing Record 23 of Set 10 | sechura
# Processing Record 24 of Set 10 | uvalde
# Processing Record 25 of Set 10 | kungurtug
# Processing Record 26 of Set 10 | da nang
# Processing Record 27 of Set 10 | wanlaweyn
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | meadow lake
# Processing Record 30 of Set 10 | riyadh
# Processing Record 31 of Set 10 | buala
# Processing Record 32 of Set 10 | kaeo
# Processing Record 33 of Set 10 | avera
# Processing Record 34 of Set 10 | norsup
# Processing Record 35 of Set 10 | rocha
# Processing Record 36 of Set 10 | melilla
# Processing Record 37 of Set 10 | opuwo
# Processing Record 38 of Set 10 | huarmey
# Processing Record 39 of Set 10 | uzhur
# Processing Record 40 of Set 10 | marstal
# Processing Record 41 of Set 10 | indramayu
# Processing Record 42 of Set 10 | vernon
# Processing Record 43 of Set 10 | bermejillo
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | antofagasta
# Processing Record 46 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 10 | emba
# Processing Record 48 of Set 10 | shostka
# Processing Record 49 of Set 10 | edd
# Processing Record 50 of Set 10 | filingue
# Processing Record 1 of Set 11 | sabha
# Processing Record 2 of Set 11 | henties bay
# Processing Record 3 of Set 11 | sicamous
# Processing Record 4 of Set 11 | inta
# Processing Record 5 of Set 11 | korla
# Processing Record 6 of Set 11 | amapa
# Processing Record 7 of Set 11 | tosya
# Processing Record 8 of Set 11 | conceicao do araguaia
# Processing Record 9 of Set 11 | znamenskoye
# Processing Record 10 of Set 11 | kalengwa
# Processing Record 11 of Set 11 | kimamba
# Processing Record 12 of Set 11 | liberal
# Processing Record 13 of Set 11 | moog
# Processing Record 14 of Set 11 | paraiso
# Processing Record 15 of Set 11 | yabelo
# Processing Record 16 of Set 11 | solon
# Processing Record 17 of Set 11 | kjopsvik
# Processing Record 18 of Set 11 | ust-koksa
# Processing Record 19 of Set 11 | saldanha
# Processing Record 20 of Set 11 | evensk
# Processing Record 21 of Set 11 | kamaishi
# Processing Record 22 of Set 11 | florence
# Processing Record 23 of Set 11 | morgan city
# Processing Record 24 of Set 11 | bandarban
# Processing Record 25 of Set 11 | mogadishu
# Processing Record 26 of Set 11 | lagunas
# Processing Record 27 of Set 11 | esperance
# Processing Record 28 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | placido de castro
# Processing Record 30 of Set 11 | vardo
# Processing Record 31 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 11 | orbe
# Processing Record 33 of Set 11 | songkhla
# Processing Record 34 of Set 11 | flinders
# Processing Record 35 of Set 11 | ulaangom
# Processing Record 36 of Set 11 | nanfeng
# Processing Record 37 of Set 11 | bulawayo
# Processing Record 38 of Set 11 | roverud
# Processing Record 39 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 40 of Set 11 | victoria
# Processing Record 41 of Set 11 | benguela
# Processing Record 42 of Set 11 | dholka
# Processing Record 43 of Set 11 | rawson
# Processing Record 44 of Set 11 | riverton
# Processing Record 45 of Set 11 | champerico
# Processing Record 46 of Set 11 | soubre
# Processing Record 47 of Set 11 | zhigansk
# Processing Record 48 of Set 11 | barcelos
# Processing Record 49 of Set 11 | agirish
# Processing Record 50 of Set 11 | ambunti
# Processing Record 1 of Set 12 | cluses
# Processing Record 2 of Set 12 | brigantine
# Processing Record 3 of Set 12 | dudinka
# Processing Record 4 of Set 12 | kisangani
# Processing Record 5 of Set 12 | sibu
# Processing Record 6 of Set 12 | tual
# Processing Record 7 of Set 12 | port hedland
# Processing Record 8 of Set 12 | hohhot
# Processing Record 9 of Set 12 | sitka
# Processing Record 10 of Set 12 | kutum
# Processing Record 11 of Set 12 | dillon
# Processing Record 12 of Set 12 | santa maria
# Processing Record 13 of Set 12 | florianopolis
# Processing Record 14 of Set 12 | adre
# Processing Record 15 of Set 12 | yithion
# City not found. Skipping...
# Processing Record 16 of Set 12 | duz
# City not found. Skipping...
# Processing Record 17 of Set 12 | belaya gora
# Processing Record 18 of Set 12 | sioux lookout
# Processing Record 19 of Set 12 | axim
# Processing Record 20 of Set 12 | salinas
# Processing Record 21 of Set 12 | cabedelo
# Processing Record 22 of Set 12 | bandar-e anzali
# Processing Record 23 of Set 12 | umm lajj
# Processing Record 24 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 12 | yarada
# Processing Record 26 of Set 12 | jishou
# Processing Record 27 of Set 12 | kashi
# Processing Record 28 of Set 12 | paracuru
# Processing Record 29 of Set 12 | milford
# Processing Record 30 of Set 12 | visnes
# Processing Record 31 of Set 12 | okhotsk
# Processing Record 32 of Set 12 | bouza
# Processing Record 33 of Set 12 | vysokogornyy
# Processing Record 34 of Set 12 | vanimo
# Processing Record 35 of Set 12 | eyl
# Processing Record 36 of Set 12 | greenville
# Processing Record 37 of Set 12 | isiro
# Processing Record 38 of Set 12 | juneau
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | cumra
# Processing Record 41 of Set 12 | liwale
# Processing Record 42 of Set 12 | mayo
# Processing Record 43 of Set 12 | isla vista
# Processing Record 44 of Set 12 | bhola
# Processing Record 45 of Set 12 | northport
# Processing Record 46 of Set 12 | quelimane
# Processing Record 47 of Set 12 | vilkija
# Processing Record 48 of Set 12 | vaitape
# Processing Record 49 of Set 12 | general bravo
# Processing Record 50 of Set 12 | itapirapua
# Processing Record 1 of Set 13 | russell
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | mumford
# Processing Record 4 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 13 | macia
# Processing Record 6 of Set 13 | lixourion
# Processing Record 7 of Set 13 | moyale
# Processing Record 8 of Set 13 | buhe
# Processing Record 9 of Set 13 | buraydah
# Processing Record 10 of Set 13 | takoradi
# Processing Record 11 of Set 13 | bathsheba
# Processing Record 12 of Set 13 | san andres
# Processing Record 13 of Set 13 | paita
# Processing Record 14 of Set 13 | huntsville
# Processing Record 15 of Set 13 | trairi
# Processing Record 16 of Set 13 | gat
# Processing Record 17 of Set 13 | pedernales
# Processing Record 18 of Set 13 | kropotkin
# Processing Record 19 of Set 13 | harbour breton
# Processing Record 20 of Set 13 | tornio
# Processing Record 21 of Set 13 | la mira
# Processing Record 22 of Set 13 | medvezhyegorsk
# Processing Record 23 of Set 13 | miri
# Processing Record 24 of Set 13 | chajul
# Processing Record 25 of Set 13 | semnan
# Processing Record 26 of Set 13 | altamira
# Processing Record 27 of Set 13 | kuchinarai
# Processing Record 28 of Set 13 | ribeira brava
# Processing Record 29 of Set 13 | kahului
# Processing Record 30 of Set 13 | saint-francois
# Processing Record 31 of Set 13 | bara
# Processing Record 32 of Set 13 | cap malheureux
# Processing Record 33 of Set 13 | talavera de la reina
# Processing Record 34 of Set 13 | kemi
# Processing Record 35 of Set 13 | stornoway
# Processing Record 36 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 13 | pandavapura
# Processing Record 38 of Set 13 | morant bay
# Processing Record 39 of Set 13 | bitung
# Processing Record 40 of Set 13 | tartagal
# Processing Record 41 of Set 13 | boralday
# Processing Record 42 of Set 13 | ciudad bolivar
# Processing Record 43 of Set 13 | port maria
# Processing Record 44 of Set 13 | quatre cocos
# Processing Record 45 of Set 13 | tocopilla
# Processing Record 46 of Set 13 | portobelo
# Processing Record 47 of Set 13 | bambanglipuro
# Processing Record 48 of Set 13 | zverinogolovskoye
# Processing Record 49 of Set 13 | sarankhola
# Processing Record 50 of Set 13 | kalulushi
# Processing Record 1 of Set 14 | wanxian
# Processing Record 2 of Set 14 | deputatskiy
# Processing Record 3 of Set 14 | bilma
# Processing Record 4 of Set 14 | ahar
# Processing Record 5 of Set 14 | kharp
# Processing Record 6 of Set 14 | lafia
# Processing Record 7 of Set 14 | lorengau
# Processing Record 8 of Set 14 | lat yao
# Processing Record 9 of Set 14 | tommot
# Processing Record 10 of Set 14 | asyut
# Processing Record 11 of Set 14 | kamogawa
# Processing Record 12 of Set 14 | varhaug
# Processing Record 13 of Set 14 | anadyr
# Processing Record 14 of Set 14 | gizo
# Processing Record 15 of Set 14 | aksarka
# Processing Record 16 of Set 14 | cilegon
# Processing Record 17 of Set 14 | byron bay
# Processing Record 18 of Set 14 | itarema
# Processing Record 19 of Set 14 | wanning
# Processing Record 20 of Set 14 | itamarandiba
# Processing Record 21 of Set 14 | ler
# Processing Record 22 of Set 14 | sungaipenuh
# Processing Record 23 of Set 14 | santa lucia
# Processing Record 24 of Set 14 | acarau
# Processing Record 25 of Set 14 | asfi
# Processing Record 26 of Set 14 | ust-omchug
# Processing Record 27 of Set 14 | chumikan
# Processing Record 28 of Set 14 | carlsbad
# Processing Record 29 of Set 14 | lae
# Processing Record 30 of Set 14 | erzin
# Processing Record 31 of Set 14 | amalapuram
# Processing Record 32 of Set 14 | carutapera
# Processing Record 33 of Set 14 | pitimbu
# Processing Record 34 of Set 14 | la plata
# Processing Record 35 of Set 14 | ugra
# Processing Record 36 of Set 14 | tessalit
# Processing Record 37 of Set 14 | shimoda
# Processing Record 38 of Set 14 | arcata
# Processing Record 39 of Set 14 | teguldet
# Processing Record 40 of Set 14 | lakes entrance
# Processing Record 41 of Set 14 | nevesinje
# Processing Record 42 of Set 14 | amahai
# Processing Record 43 of Set 14 | tongren
# Processing Record 44 of Set 14 | phrai bung
# City not found. Skipping...
# Processing Record 45 of Set 14 | skibbereen
# Processing Record 46 of Set 14 | maceio
# Processing Record 47 of Set 14 | mehamn
# Processing Record 48 of Set 14 | bubaque
# Processing Record 49 of Set 14 | aleksandrow kujawski
# Processing Record 50 of Set 14 | koungou
# Processing Record 1 of Set 15 | antsohihy
# Processing Record 2 of Set 15 | ulladulla
# Processing Record 3 of Set 15 | mateare
# Processing Record 4 of Set 15 | makariv
# Processing Record 5 of Set 15 | gigmoto
# Processing Record 6 of Set 15 | san jose de los arroyos
# City not found. Skipping...
# Processing Record 7 of Set 15 | harrismith
# Processing Record 8 of Set 15 | samarai
# Processing Record 9 of Set 15 | beyneu
# Processing Record 10 of Set 15 | leczna
# Processing Record 11 of Set 15 | sao pedro do sul
# Processing Record 12 of Set 15 | birao
# Processing Record 13 of Set 15 | harper
# Processing Record 14 of Set 15 | toamasina
# Processing Record 15 of Set 15 | san jose
# Processing Record 16 of Set 15 | villa carlos paz
# Processing Record 17 of Set 15 | abu samrah
# Processing Record 18 of Set 15 | elban
# Processing Record 19 of Set 15 | sladkovo
# Processing Record 20 of Set 15 | fuxin
# Processing Record 21 of Set 15 | kulhudhuffushi
# Processing Record 22 of Set 15 | uruguaiana
# Processing Record 23 of Set 15 | manyana
# Processing Record 24 of Set 15 | narwar
# Processing Record 25 of Set 15 | sorland
# Processing Record 26 of Set 15 | hay river
# Processing Record 27 of Set 15 | mikkeli
# Processing Record 28 of Set 15 | kitimat
# Processing Record 29 of Set 15 | jaguaribe
# Processing Record 30 of Set 15 | mabaruma
# Processing Record 31 of Set 15 | aleksandrov gay
# Processing Record 32 of Set 15 | megion
# Processing Record 33 of Set 15 | batagay
# Processing Record 34 of Set 15 | mareeba
# Processing Record 35 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 15 | vostok
# Processing Record 37 of Set 15 | torit
# Processing Record 38 of Set 15 | guilin
# Processing Record 39 of Set 15 | malyye derbety
# Processing Record 40 of Set 15 | sinegorye
# Processing Record 41 of Set 15 | novosineglazovskiy
# Processing Record 42 of Set 15 | sept-iles
# Processing Record 43 of Set 15 | dhidhdhoo
# Processing Record 44 of Set 15 | nadym
# Processing Record 45 of Set 15 | pitea
# Processing Record 46 of Set 15 | krasnogorsk
# Processing Record 47 of Set 15 | arlit
# Processing Record 48 of Set 15 | umba
# Processing Record 49 of Set 15 | timizart
# Processing Record 50 of Set 15 | puerto colombia
# Processing Record 1 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 16 | amarillo
# Processing Record 3 of Set 16 | kousseri
# Processing Record 4 of Set 16 | mount gambier
# Processing Record 5 of Set 16 | soyo
# Processing Record 6 of Set 16 | itapetinga
# Processing Record 7 of Set 16 | dubenskiy
# City not found. Skipping...
# Processing Record 8 of Set 16 | alta floresta
# Processing Record 9 of Set 16 | nabire
# Processing Record 10 of Set 16 | manaira
# Processing Record 11 of Set 16 | kabin buri
# Processing Record 12 of Set 16 | tete
# Processing Record 13 of Set 16 | katangli
# Processing Record 14 of Set 16 | port hueneme
# Processing Record 15 of Set 16 | tombouctou
# Processing Record 16 of Set 16 | kijang
# Processing Record 17 of Set 16 | sibolga
# Processing Record 18 of Set 16 | eston
# Processing Record 19 of Set 16 | svetlyy
# Processing Record 20 of Set 16 | goya
# Processing Record 21 of Set 16 | taber
# Processing Record 22 of Set 16 | kolpny
# Processing Record 23 of Set 16 | hoquiam
# Processing Record 24 of Set 16 | belyy yar
# Processing Record 25 of Set 16 | bodden town
# Processing Record 26 of Set 16 | belmonte
# Processing Record 27 of Set 16 | abha
# Processing Record 28 of Set 16 | kavieng
# Processing Record 29 of Set 16 | hirara
# Processing Record 30 of Set 16 | halifax
# Processing Record 31 of Set 16 | uralskiy
# City not found. Skipping...
# Processing Record 32 of Set 16 | catuday
# Processing Record 33 of Set 16 | lazarev
# Processing Record 34 of Set 16 | ust-karsk
# Processing Record 35 of Set 16 | buritis
# Processing Record 36 of Set 16 | eureka
# Processing Record 37 of Set 16 | zhangye
# Processing Record 38 of Set 16 | aldan
# Processing Record 39 of Set 16 | gidam
# Processing Record 40 of Set 16 | kyaikto
# Processing Record 41 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 16 | mayumba
# Processing Record 43 of Set 16 | mao
# Processing Record 44 of Set 16 | kenai
# Processing Record 45 of Set 16 | puro
# Processing Record 46 of Set 16 | kalianget
# Processing Record 47 of Set 16 | serenje
# Processing Record 48 of Set 16 | camana
# Processing Record 49 of Set 16 | embu
# Processing Record 50 of Set 16 | chake chake
# Processing Record 1 of Set 17 | dumai
# Processing Record 2 of Set 17 | nyurba
# Processing Record 3 of Set 17 | tatsinskaya
# City not found. Skipping...
# Processing Record 4 of Set 17 | nizhneangarsk
# Processing Record 5 of Set 17 | goderich
# Processing Record 6 of Set 17 | olavarria
# Processing Record 7 of Set 17 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 17 | trinidad
# Processing Record 9 of Set 17 | moose factory
# Processing Record 10 of Set 17 | turayf
# Processing Record 11 of Set 17 | lemesos
# City not found. Skipping...
# Processing Record 12 of Set 17 | karymskoye
# Processing Record 13 of Set 17 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 17 | hovd
# Processing Record 15 of Set 17 | meulaboh
# Processing Record 16 of Set 17 | dickinson
# Processing Record 17 of Set 17 | linjiang
# Processing Record 18 of Set 17 | alihe
# Processing Record 19 of Set 17 | festus
# Processing Record 20 of Set 17 | baishishan
# Processing Record 21 of Set 17 | shalya
# Processing Record 22 of Set 17 | polyarnyy
# Processing Record 23 of Set 17 | humboldt
# Processing Record 24 of Set 17 | burns lake
# Processing Record 25 of Set 17 | zamania
# Processing Record 26 of Set 17 | kudahuvadhoo
# Processing Record 27 of Set 17 | kondinskoye
# Processing Record 28 of Set 17 | kapuskasing
# Processing Record 29 of Set 17 | yar-sale
# Processing Record 30 of Set 17 | burnie
# Processing Record 31 of Set 17 | musoma
# Processing Record 32 of Set 17 | hobara
# Processing Record 33 of Set 17 | ulaanbaatar
# Processing Record 34 of Set 17 | alenquer
# Processing Record 35 of Set 17 | kharan
# Processing Record 36 of Set 17 | turbat
# Processing Record 37 of Set 17 | galle
# Processing Record 38 of Set 17 | manzil tamim
# City not found. Skipping...
# Processing Record 39 of Set 17 | luau
# Processing Record 40 of Set 17 | khanpur
# Processing Record 41 of Set 17 | polje
# Processing Record 42 of Set 17 | doha
# Processing Record 43 of Set 17 | suntar
# Processing Record 44 of Set 17 | bajo baudo
# City not found. Skipping...
# Processing Record 45 of Set 17 | tigre
# Processing Record 46 of Set 17 | lapy
# Processing Record 47 of Set 17 | butte
# Processing Record 48 of Set 17 | sao filipe
# Processing Record 49 of Set 17 | maltahohe
# Processing Record 50 of Set 17 | lima
# Processing Record 1 of Set 18 | urucara
# Processing Record 2 of Set 18 | beira
# Processing Record 3 of Set 18 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 18 | gazanjyk
# Processing Record 5 of Set 18 | novochernorechenskiy
# Processing Record 6 of Set 18 | pionerskiy
# Processing Record 7 of Set 18 | obluche
# City not found. Skipping...
# Processing Record 8 of Set 18 | yumen
# Processing Record 9 of Set 18 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 18 | qaqortoq
# Processing Record 11 of Set 18 | tailai
# Processing Record 12 of Set 18 | kvitok
# Processing Record 13 of Set 18 | ust-ilimsk
# Processing Record 14 of Set 18 | doba
# Processing Record 15 of Set 18 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 18 | tabou
# Processing Record 17 of Set 18 | tolosa
# Processing Record 18 of Set 18 | pinheiro machado
# Processing Record 19 of Set 18 | khrebtovaya
# Processing Record 20 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 18 | manokwari
# Processing Record 22 of Set 18 | caernarfon
# Processing Record 23 of Set 18 | port lincoln
# Processing Record 24 of Set 18 | novobessergenevka
# Processing Record 25 of Set 18 | mau
# Processing Record 26 of Set 18 | achacachi
# Processing Record 27 of Set 18 | andselv
# City not found. Skipping...
# Processing Record 28 of Set 18 | ouegoa
# Processing Record 29 of Set 18 | puerto leguizamo
# Processing Record 30 of Set 18 | severodvinsk
# Processing Record 31 of Set 18 | paytug
# City not found. Skipping...
# Processing Record 32 of Set 18 | dandong
# Processing Record 33 of Set 18 | camabatela
# Processing Record 34 of Set 18 | vilyuysk
# Processing Record 35 of Set 18 | probolinggo
# Processing Record 36 of Set 18 | illapel
# Processing Record 37 of Set 18 | piacabucu
# Processing Record 38 of Set 18 | reconquista
# Processing Record 39 of Set 18 | izumo
# Processing Record 40 of Set 18 | kyle
# Processing Record 41 of Set 18 | hella
# Processing Record 42 of Set 18 | yebaishou
# Processing Record 43 of Set 18 | vanavara
# Processing Record 44 of Set 18 | ngunguru
# Processing Record 45 of Set 18 | constantine
# Processing Record 46 of Set 18 | lensk
# Processing Record 47 of Set 18 | nottuln
# Processing Record 48 of Set 18 | changping
# Processing Record 49 of Set 18 | azare
# Processing Record 50 of Set 18 | muromtsevo
# Processing Record 1 of Set 19 | back mountain
# Processing Record 2 of Set 19 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 19 | tondano
# Processing Record 4 of Set 19 | nushki
# Processing Record 5 of Set 19 | moron
# Processing Record 6 of Set 19 | saint-louis
# Processing Record 7 of Set 19 | beloha
# Processing Record 8 of Set 19 | port pirie
# Processing Record 9 of Set 19 | vila franca do campo
# Processing Record 10 of Set 19 | basarabeasca
# Processing Record 11 of Set 19 | urumqi
# Processing Record 12 of Set 19 | duobao
# Processing Record 13 of Set 19 | kasempa
# Processing Record 14 of Set 19 | ascension
# Processing Record 15 of Set 19 | porosozero
# Processing Record 16 of Set 19 | karwar
# Processing Record 17 of Set 19 | zabid
# Processing Record 18 of Set 19 | richards bay
# Processing Record 19 of Set 19 | chandbali
# Processing Record 20 of Set 19 | sakakah
# Processing Record 21 of Set 19 | nurota
# Processing Record 22 of Set 19 | kiunga
# Processing Record 23 of Set 19 | kathu
# Processing Record 24 of Set 19 | ust-tsilma
# Processing Record 25 of Set 19 | monte patria
# Processing Record 26 of Set 19 | ferrol
# Processing Record 27 of Set 19 | sigli
# Processing Record 28 of Set 19 | vila
# Processing Record 29 of Set 19 | encheng
# Processing Record 30 of Set 19 | vaxjo
# Processing Record 31 of Set 19 | monze
# Processing Record 32 of Set 19 | atbasar
# Processing Record 33 of Set 19 | amarwara
# Processing Record 34 of Set 19 | san rafael
# Processing Record 35 of Set 19 | kieta
# Processing Record 36 of Set 19 | sitrah
# Processing Record 37 of Set 19 | vredendal
# Processing Record 38 of Set 19 | ballina
# Processing Record 39 of Set 19 | muros
# Processing Record 40 of Set 19 | gao
# Processing Record 41 of Set 19 | black forest
# Processing Record 42 of Set 19 | manado
# Processing Record 43 of Set 19 | monrovia
# Processing Record 44 of Set 19 | yefremov
# Processing Record 45 of Set 19 | dwarka
# Processing Record 46 of Set 19 | acari
# Processing Record 47 of Set 19 | tromso
# Processing Record 48 of Set 19 | radstadt
# Processing Record 49 of Set 19 | nguruka
# Processing Record 50 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 20 | stepnoye
# Processing Record 2 of Set 20 | pervomayskiy
# Processing Record 3 of Set 20 | atlantic city
# Processing Record 4 of Set 20 | ukiah
# Processing Record 5 of Set 20 | sarkand
# Processing Record 6 of Set 20 | hearst
# Processing Record 7 of Set 20 | honiara
# Processing Record 8 of Set 20 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 20 | coahuayana
# Processing Record 10 of Set 20 | ishigaki
# Processing Record 11 of Set 20 | auki
# Processing Record 12 of Set 20 | santa isabel do rio negro
# Processing Record 13 of Set 20 | chara
# Processing Record 14 of Set 20 | apatity
# Processing Record 15 of Set 20 | barstow
# Processing Record 16 of Set 20 | rauma
# Processing Record 17 of Set 20 | mandalgovi
# Processing Record 18 of Set 20 | la asuncion
# Processing Record 19 of Set 20 | bosaso
# Processing Record 20 of Set 20 | mnogovershinnyy
# Processing Record 21 of Set 20 | aljezur
# Processing Record 22 of Set 20 | shingu
# Processing Record 23 of Set 20 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 20 | biak
# Processing Record 25 of Set 20 | capitan bado
# Processing Record 26 of Set 20 | bar harbor
# Processing Record 27 of Set 20 | calama
# Processing Record 28 of Set 20 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 20 | bloemfontein
# Processing Record 30 of Set 20 | port augusta
# Processing Record 31 of Set 20 | saint-augustin
# Processing Record 32 of Set 20 | skjervoy
# Processing Record 33 of Set 20 | papara
# Processing Record 34 of Set 20 | juba
# Processing Record 35 of Set 20 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 20 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 20 | bereda
# Processing Record 38 of Set 20 | steinbach
# Processing Record 39 of Set 20 | kishangarh
# Processing Record 40 of Set 20 | vigrestad
# Processing Record 41 of Set 20 | troitsko-pechorsk
# Processing Record 42 of Set 20 | sao jose da coroa grande
# Processing Record 43 of Set 20 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 20 | ouesso
# Processing Record 45 of Set 20 | betioky
# Processing Record 46 of Set 20 | madinat sittah uktubar
# Processing Record 47 of Set 20 | lumphat
# Processing Record 48 of Set 20 | balakhta
# Processing Record 49 of Set 20 | qinhuangdao
# Processing Record 50 of Set 20 | gasa
# Processing Record 1 of Set 21 | yialos
# City not found. Skipping...
# Processing Record 2 of Set 21 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 21 | guayama
# Processing Record 4 of Set 21 | custodia
# Processing Record 5 of Set 21 | peace river
# Processing Record 6 of Set 21 | kolobrzeg
# Processing Record 7 of Set 21 | puerto cabezas
# Processing Record 8 of Set 21 | bichena
# Processing Record 9 of Set 21 | marawi
# Processing Record 10 of Set 21 | unai
# Processing Record 11 of Set 21 | ginir
# Processing Record 12 of Set 21 | baghdad
# Processing Record 13 of Set 21 | arcachon
# Processing Record 14 of Set 21 | chicama
# Processing Record 15 of Set 21 | san juan
# Processing Record 16 of Set 21 | uchana
# Processing Record 17 of Set 21 | mocuba
# Processing Record 18 of Set 21 | penzance
# Processing Record 19 of Set 21 | gorahun
# Processing Record 20 of Set 21 | karlstad
# Processing Record 21 of Set 21 | bataipora
# Processing Record 22 of Set 21 | brownwood
# Processing Record 23 of Set 21 | issia
# Processing Record 24 of Set 21 | camacha
# Processing Record 25 of Set 21 | yarmouth
# Processing Record 26 of Set 21 | punta alta
# Processing Record 27 of Set 21 | zlatoustovsk
# City not found. Skipping...
# Processing Record 28 of Set 21 | berdigestyakh
# Processing Record 29 of Set 21 | pahrump
# Processing Record 30 of Set 21 | karatuzskoye
# Processing Record 31 of Set 21 | soe
# Processing Record 32 of Set 21 | urdoma
# Processing Record 33 of Set 21 | ntoum
# Processing Record 34 of Set 21 | bestobe
# Processing Record 35 of Set 21 | gander
# Processing Record 36 of Set 21 | salinopolis
# Processing Record 37 of Set 21 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 21 | herat
# Processing Record 39 of Set 21 | sidney
# Processing Record 40 of Set 21 | balimo
# City not found. Skipping...
# Processing Record 41 of Set 21 | marathokambos
# City not found. Skipping...
# Processing Record 42 of Set 21 | dubbo
# Processing Record 43 of Set 21 | itupiranga
# Processing Record 44 of Set 21 | ketchikan
# Processing Record 45 of Set 21 | hailar
# Processing Record 46 of Set 21 | varangaon
# Processing Record 47 of Set 21 | warri
# Processing Record 48 of Set 21 | pangkalanbuun
# Processing Record 49 of Set 21 | college
# Processing Record 50 of Set 21 | tres arroyos
# Processing Record 1 of Set 22 | tenenkou
# Processing Record 2 of Set 22 | vinh
# Processing Record 3 of Set 22 | arman
# Processing Record 4 of Set 22 | colares
# Processing Record 5 of Set 22 | kindia
# Processing Record 6 of Set 22 | tiznit
# Processing Record 7 of Set 22 | terrace bay
# Processing Record 8 of Set 22 | ustka
# Processing Record 9 of Set 22 | jacmel
# Processing Record 10 of Set 22 | nova petropolis
# Processing Record 11 of Set 22 | elizabeth city
# Processing Record 12 of Set 22 | la paz
# Processing Record 13 of Set 22 | kurakh
# Processing Record 14 of Set 22 | cabatuan
# Processing Record 15 of Set 22 | visby
# Processing Record 16 of Set 22 | thunder bay
# Processing Record 17 of Set 22 | yasnyy
# Processing Record 18 of Set 22 | nagyszenas
# Processing Record 19 of Set 22 | swan river
# Processing Record 20 of Set 22 | shakawe
# Processing Record 21 of Set 22 | navolato
# Processing Record 22 of Set 22 | san carlos de bariloche
# Processing Record 23 of Set 22 | asmar
# Processing Record 24 of Set 22 | puerto escondido
# Processing Record 25 of Set 22 | sopiste
# City not found. Skipping...
# Processing Record 26 of Set 22 | durban
# Processing Record 27 of Set 22 | xiuyan
# Processing Record 28 of Set 22 | kralendijk
# Processing Record 29 of Set 22 | green river
# Processing Record 30 of Set 22 | yokadouma
# Processing Record 31 of Set 22 | cacule
# Processing Record 32 of Set 22 | kamenka
# Processing Record 33 of Set 22 | pangody
# Processing Record 34 of Set 22 | waingapu
# Processing Record 35 of Set 22 | campos altos
# Processing Record 36 of Set 22 | nuevo progreso
# Processing Record 37 of Set 22 | batsfjord
# Processing Record 38 of Set 22 | kinsale
# Processing Record 39 of Set 22 | andenes
# ...
# Processing Record 45 of Set 37 | great yarmouth
# Processing Record 46 of Set 37 | north bend
# Processing Record 47 of Set 37 | burkhala
# City not found. Skipping...
# Processing Record 48 of Set 37 | ust-maya
# Processing Record 49 of Set 37 | carson city
# Processing Record 50 of Set 37 | nova olinda do norte
# Processing Record 1 of Set 38 | lesogorsk
# Processing Record 2 of Set 38 | dongsheng
# Processing Record 3 of Set 38 | taywarah
# Processing Record 4 of Set 38 | seybaplaya
# Processing Record 5 of Set 38 | jarvakandi
# Processing Record 6 of Set 38 | caronport
# Processing Record 7 of Set 38 | cutro
# Processing Record 8 of Set 38 | borger
# Processing Record 9 of Set 38 | kynashiv
# Processing Record 10 of Set 38 | safaga
# Processing Record 11 of Set 38 | novopokrovka
# Processing Record 12 of Set 38 | soroti
# Processing Record 13 of Set 38 | derzhavinsk
# Processing Record 14 of Set 38 | mugumu
# Processing Record 15 of Set 38 | manuk mangkaw
# Processing Record 16 of Set 38 | bolobo
# Processing Record 17 of Set 38 | tecoanapa
# Processing Record 18 of Set 38 | ipatovo
# Processing Record 19 of Set 38 | nikel
# Processing Record 20 of Set 38 | janakpur road
# City not found. Skipping...
# Processing Record 21 of Set 38 | lashio
# Processing Record 22 of Set 38 | parry sound
# Processing Record 23 of Set 38 | wasilla
# Processing Record 24 of Set 38 | coxim
# Processing Record 25 of Set 38 | naftah
# City not found. Skipping...
# Processing Record 26 of Set 38 | novyy urgal
# Processing Record 27 of Set 38 | vitim
# Processing Record 28 of Set 38 | great bend
# Processing Record 29 of Set 38 | satinka
# Processing Record 30 of Set 38 | hof
# Processing Record 31 of Set 38 | agbor
# Processing Record 32 of Set 38 | den helder
# Processing Record 33 of Set 38 | odweyne
# Processing Record 34 of Set 38 | panalingaan
# Processing Record 35 of Set 38 | briancon
# Processing Record 36 of Set 38 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 38 | aktau
# Processing Record 38 of Set 38 | black river
# Processing Record 39 of Set 38 | aquiraz
# Processing Record 40 of Set 38 | kostomuksha
# Processing Record 41 of Set 38 | asuncion
# Processing Record 42 of Set 38 | shitkino
# Processing Record 43 of Set 38 | maun
# Processing Record 44 of Set 38 | porto walter
# Processing Record 45 of Set 38 | emerald
# Processing Record 46 of Set 38 | kushmurun
# Processing Record 47 of Set 38 | manacapuru
# Processing Record 48 of Set 38 | strathblane
# Processing Record 49 of Set 38 | honningsvag
# Processing Record 50 of Set 38 | bairiki
# Processing Record 1 of Set 39 | bac can
# City not found. Skipping...
# Processing Record 2 of Set 39 | general roca
# Processing Record 3 of Set 39 | ossora
# Processing Record 4 of Set 39 | san ramon
# Processing Record 5 of Set 39 | eenhana
# Processing Record 6 of Set 39 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 39 | pop
# Processing Record 8 of Set 39 | matara
# Processing Record 9 of Set 39 | mosquera
# Processing Record 10 of Set 39 | mount hagen
# Processing Record 11 of Set 39 | palembang
# Processing Record 12 of Set 39 | mwinilunga
# Processing Record 13 of Set 39 | odemis
# City not found. Skipping...
# Processing Record 14 of Set 39 | kerema
# Processing Record 15 of Set 39 | litovko
# Processing Record 16 of Set 39 | bozoum
# Processing Record 17 of Set 39 | barao de melgaco
# Processing Record 18 of Set 39 | miranda
# Processing Record 19 of Set 39 | synya
# Processing Record 20 of Set 39 | akdepe
# Processing Record 21 of Set 39 | raudeberg
# Processing Record 22 of Set 39 | amga
# Processing Record 23 of Set 39 | murshidabad
# Processing Record 24 of Set 39 | santa isabel
# Processing Record 25 of Set 39 | itatuba
# Processing Record 26 of Set 39 | meybod
# Processing Record 27 of Set 39 | kaya
# Processing Record 28 of Set 39 | toba
# Processing Record 29 of Set 39 | sirajganj
# Processing Record 30 of Set 39 | denpasar
# Processing Record 31 of Set 39 | ryazan
# Processing Record 32 of Set 39 | mbandaka
# Processing Record 33 of Set 39 | les escoumins
# Processing Record 34 of Set 39 | yala
# Processing Record 35 of Set 39 | sita buzaului
# Processing Record 36 of Set 39 | varjota
# Processing Record 37 of Set 39 | pailon
# Processing Record 38 of Set 39 | gilbues
# Processing Record 39 of Set 39 | inuvik
# Processing Record 40 of Set 39 | manuel doblado
# City not found. Skipping...
# Processing Record 41 of Set 39 | mpanda
# Processing Record 42 of Set 39 | fjerritslev
# Processing Record 43 of Set 39 | narasannapeta
# Processing Record 44 of Set 39 | shar
# Processing Record 45 of Set 39 | gaya
# Processing Record 46 of Set 39 | licata
# Processing Record 47 of Set 39 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 39 | felanitx
# Processing Record 49 of Set 39 | durango
# Processing Record 50 of Set 39 | havelock
# Processing Record 1 of Set 40 | helong
# Processing Record 2 of Set 40 | coihueco
# Processing Record 3 of Set 40 | eydhafushi
# Processing Record 4 of Set 40 | numan
# Processing Record 5 of Set 40 | mkokotoni
# Processing Record 6 of Set 40 | havoysund
# Processing Record 7 of Set 40 | newport
# Processing Record 8 of Set 40 | edremit
# Processing Record 9 of Set 40 | kurumkan
# Processing Record 10 of Set 40 | chute-aux-outardes
# Processing Record 11 of Set 40 | teahupoo
# Processing Record 12 of Set 40 | usiacuri
# Processing Record 13 of Set 40 | irbeyskoye
# Processing Record 14 of Set 40 | wilmington
# Processing Record 15 of Set 40 | itabera
# Processing Record 16 of Set 40 | diebougou
# Processing Record 17 of Set 40 | la libertad
# Processing Record 18 of Set 40 | verkhnevilyuysk
# Processing Record 19 of Set 40 | biskamzha
# Processing Record 20 of Set 40 | sandakan
# Processing Record 21 of Set 40 | shasta lake
# Processing Record 22 of Set 40 | oroquieta
# Processing Record 23 of Set 40 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 40 | hede
# Processing Record 25 of Set 40 | bardiyah
# Processing Record 26 of Set 40 | sankt polten
# Processing Record 27 of Set 40 | beloomut
# Processing Record 28 of Set 40 | padre paraiso
# Processing Record 29 of Set 40 | turbo
# Processing Record 30 of Set 40 | huallanca
# Processing Record 31 of Set 40 | magsaysay
# Processing Record 32 of Set 40 | sakaide
# Processing Record 33 of Set 40 | matay
# Processing Record 34 of Set 40 | dayong
# Processing Record 35 of Set 40 | sinjar
# Processing Record 36 of Set 40 | sandwick
# Processing Record 37 of Set 40 | negombo
# Processing Record 38 of Set 40 | wanderlandia
# City not found. Skipping...
# Processing Record 39 of Set 40 | teneguiban
# City not found. Skipping...
# Processing Record 40 of Set 40 | miramar
# Processing Record 41 of Set 40 | pandan
# Processing Record 42 of Set 40 | mandera
# Processing Record 43 of Set 40 | conde
# Processing Record 44 of Set 40 | aasiaat
# Processing Record 45 of Set 40 | antakya
# Processing Record 46 of Set 40 | tra vinh
# Processing Record 47 of Set 40 | shahreza
# Processing Record 48 of Set 40 | miracema do tocantins
# Processing Record 49 of Set 40 | hukuntsi
# Processing Record 50 of Set 40 | redhakhol
# City not found. Skipping...
# Processing Record 1 of Set 41 | gazimurskiy zavod
# Processing Record 2 of Set 41 | aksarayskiy
# Processing Record 3 of Set 41 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 41 | makuyuni
# Processing Record 5 of Set 41 | podgornoye
# Processing Record 6 of Set 41 | tanete
# Processing Record 7 of Set 41 | dalbandin
# Processing Record 8 of Set 41 | vallenar
# Processing Record 9 of Set 41 | martil
# Processing Record 10 of Set 41 | aragarcas
# Processing Record 11 of Set 41 | dangriga
# Processing Record 12 of Set 41 | bongandanga
# Processing Record 13 of Set 41 | selma
# Processing Record 14 of Set 41 | narva-joesuu
# Processing Record 15 of Set 41 | cornwall
# Processing Record 16 of Set 41 | clinton
# Processing Record 17 of Set 41 | yumbel
# Processing Record 18 of Set 41 | pokhara
# Processing Record 19 of Set 41 | aranos
# Processing Record 20 of Set 41 | truth or consequences
# Processing Record 21 of Set 41 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 41 | capao da canoa
# Processing Record 23 of Set 41 | chubbuck
# Processing Record 24 of Set 41 | artyom
# Processing Record 25 of Set 41 | ileza
# Processing Record 26 of Set 41 | camapua
# Processing Record 27 of Set 41 | foam lake
# Processing Record 28 of Set 41 | amurzet
# Processing Record 29 of Set 41 | straumen
# Processing Record 30 of Set 41 | basco
# Processing Record 31 of Set 41 | agde
# Processing Record 32 of Set 41 | dicabisagan
# Processing Record 33 of Set 41 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 41 | wuan
# Processing Record 35 of Set 41 | ozinki
# Processing Record 36 of Set 41 | seymchan
# Processing Record 37 of Set 41 | bujaru
# Processing Record 38 of Set 41 | grao mogol
# Processing Record 39 of Set 41 | nianzishan
# Processing Record 40 of Set 41 | medicine hat
# Processing Record 41 of Set 41 | khor
# Processing Record 42 of Set 41 | kindu
# Processing Record 43 of Set 41 | conneaut
# Processing Record 44 of Set 41 | ordzhonikidze
# Processing Record 45 of Set 41 | bagacay
# Processing Record 46 of Set 41 | nimbahera
# Processing Record 47 of Set 41 | azrow
# City not found. Skipping...
# Processing Record 48 of Set 41 | serowe
# Processing Record 49 of Set 41 | pontalina
# Processing Record 50 of Set 41 | rehoboth
# Processing Record 1 of Set 42 | laranjeiras do sul
# Processing Record 2 of Set 42 | sukhobezvodnoye
# Processing Record 3 of Set 42 | magistralnyy
# Processing Record 4 of Set 42 | coronado
# Processing Record 5 of Set 42 | north battleford
# Processing Record 6 of Set 42 | uarini
# Processing Record 7 of Set 42 | canala
# Processing Record 8 of Set 42 | joshimath
# Processing Record 9 of Set 42 | muzhi
# Processing Record 10 of Set 42 | bulgan
# Processing Record 11 of Set 42 | abu zabad
# Processing Record 12 of Set 42 | akyab
# Processing Record 13 of Set 42 | jiuquan
# Processing Record 14 of Set 42 | konakovo
# Processing Record 15 of Set 42 | gbarnga
# Processing Record 16 of Set 42 | katav-ivanovsk
# Processing Record 17 of Set 42 | ucluelet
# Processing Record 18 of Set 42 | maiduguri
# Processing Record 19 of Set 42 | fairmont
# Processing Record 20 of Set 42 | assiniboia
# Processing Record 21 of Set 42 | kendari
# Processing Record 22 of Set 42 | pimenta bueno
# Processing Record 23 of Set 42 | boldumsaz
# Processing Record 24 of Set 42 | karousades
# City not found. Skipping...
# Processing Record 25 of Set 42 | luena
# Processing Record 26 of Set 42 | feijo
# Processing Record 27 of Set 42 | jintur
# Processing Record 28 of Set 42 | tanout
# Processing Record 29 of Set 42 | lasem
# Processing Record 30 of Set 42 | boone
# Processing Record 31 of Set 42 | marienburg
# Processing Record 32 of Set 42 | krasnoarmeysk
# Processing Record 33 of Set 42 | iiyama
# Processing Record 34 of Set 42 | tubmanburg
# Processing Record 35 of Set 42 | marrakesh
# Processing Record 36 of Set 42 | tukuran
# Processing Record 37 of Set 42 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 38 of Set 42 | gornozavodsk
# Processing Record 39 of Set 42 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 40 of Set 42 | bonnyville
# Processing Record 41 of Set 42 | abu kamal
# Processing Record 42 of Set 42 | nova vicosa
# Processing Record 43 of Set 42 | bam
# Processing Record 44 of Set 42 | camaqua
# Processing Record 45 of Set 42 | doka
# Processing Record 46 of Set 42 | umm kaddadah
# Processing Record 47 of Set 42 | oltedal
# Processing Record 48 of Set 42 | cananea
# Processing Record 49 of Set 42 | ordu
# Processing Record 50 of Set 42 | fuerte olimpo
# Processing Record 1 of Set 43 | saint-georges
# Processing Record 2 of Set 43 | cansancao
# Processing Record 3 of Set 43 | palencia
# Processing Record 4 of Set 43 | stanger
# Processing Record 5 of Set 43 | mahibadhoo
# Processing Record 6 of Set 43 | zemio
# Processing Record 7 of Set 43 | haifa
# Processing Record 8 of Set 43 | lethbridge
# Processing Record 9 of Set 43 | ploemeur
# Processing Record 10 of Set 43 | terra santa
# Processing Record 11 of Set 43 | premia de mar
# Processing Record 12 of Set 43 | kayan
# Processing Record 13 of Set 43 | longido
# Processing Record 14 of Set 43 | awjilah
# Processing Record 15 of Set 43 | niamey
# Processing Record 16 of Set 43 | felidhoo
# City not found. Skipping...
# Processing Record 17 of Set 43 | ryotsu
# Processing Record 18 of Set 43 | otavi
# Processing Record 19 of Set 43 | sinazongwe
# Processing Record 20 of Set 43 | kangasala
# Processing Record 21 of Set 43 | gloversville
# Processing Record 22 of Set 43 | tariba
# Processing Record 23 of Set 43 | severnoye
# Processing Record 24 of Set 43 | kitchener
# Processing Record 25 of Set 43 | satellite beach
# Processing Record 26 of Set 43 | trelew
# Processing Record 27 of Set 43 | bolgatanga
# Processing Record 28 of Set 43 | navsari
# Processing Record 29 of Set 43 | utete
# Processing Record 30 of Set 43 | sol-iletsk
# Processing Record 31 of Set 43 | roman
# Processing Record 32 of Set 43 | presidencia roque saenz pena
# Processing Record 33 of Set 43 | merritt island
# Processing Record 34 of Set 43 | soure
# Processing Record 35 of Set 43 | tarhunah
# City not found. Skipping...
# Processing Record 36 of Set 43 | namtsy
# Processing Record 37 of Set 43 | la foa
# Processing Record 38 of Set 43 | izhevskoye
# Processing Record 39 of Set 43 | korcula
# Processing Record 40 of Set 43 | burla
# Processing Record 41 of Set 43 | ofaqim
# Processing Record 42 of Set 43 | thiruvananthapuram
# Processing Record 43 of Set 43 | granada
# Processing Record 44 of Set 43 | tevaitoa
# Processing Record 45 of Set 43 | astoria
# Processing Record 46 of Set 43 | sao miguel do iguacu
# Processing Record 47 of Set 43 | bandar
# Processing Record 48 of Set 43 | maumere
# Processing Record 49 of Set 43 | norrtalje
# Processing Record 50 of Set 43 | kepala batas
# Processing Record 1 of Set 44 | price
# Processing Record 2 of Set 44 | tucurui
# Processing Record 3 of Set 44 | nakhon phanom
# Processing Record 4 of Set 44 | at-bashi
# Processing Record 5 of Set 44 | susanville
# Processing Record 6 of Set 44 | mumbwa
# Processing Record 7 of Set 44 | novobiryusinskiy
# Processing Record 8 of Set 44 | prince george
# Processing Record 9 of Set 44 | coruripe
# Processing Record 10 of Set 44 | mingyue
# Processing Record 11 of Set 44 | gezing
# Processing Record 12 of Set 44 | kodinsk
# Processing Record 13 of Set 44 | noyabrsk
# Processing Record 14 of Set 44 | kosh-agach
# Processing Record 15 of Set 44 | waitara
# Processing Record 16 of Set 44 | kotaparh
# Processing Record 17 of Set 44 | el penon
# Processing Record 18 of Set 44 | lodja
# Processing Record 19 of Set 44 | tallahassee
# Processing Record 20 of Set 44 | tandil
# Processing Record 21 of Set 44 | concepcion del oro
# Processing Record 22 of Set 44 | saint-vallier
# Processing Record 23 of Set 44 | high rock
# Processing Record 24 of Set 44 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 44 | shitanjing
# Processing Record 26 of Set 44 | rosetown
# Processing Record 27 of Set 44 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 44 | kincardine
# Processing Record 29 of Set 44 | zaragoza
# Processing Record 30 of Set 44 | grojec
# Processing Record 31 of Set 44 | sitangkai
# Processing Record 32 of Set 44 | chiusi
# Processing Record 33 of Set 44 | uglekamensk
# Processing Record 34 of Set 44 | puteyets
# Processing Record 35 of Set 44 | manzil salim
# Processing Record 36 of Set 44 | fortuna foothills
# Processing Record 37 of Set 44 | marica
# Processing Record 38 of Set 44 | garowe
# Processing Record 39 of Set 44 | castro daire
# Processing Record 40 of Set 44 | putnam
# Processing Record 41 of Set 44 | titay
# Processing Record 42 of Set 44 | pimentel
# Processing Record 43 of Set 44 | cervo
# Processing Record 44 of Set 44 | nakambala
# Processing Record 45 of Set 44 | kargasok
# Processing Record 46 of Set 44 | anupgarh
# Processing Record 47 of Set 44 | san francisco del mar
# Processing Record 48 of Set 44 | qarqin
# Processing Record 49 of Set 44 | gambiran
# Processing Record 50 of Set 44 | kirove
# Processing Record 1 of Set 45 | tyrma
# Processing Record 2 of Set 45 | nerchinskiy zavod
# Processing Record 3 of Set 45 | caramoan
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
len(city_data)
# Out:
# 2030

# %%
# Create a DataFrame of the city weather data. 
# Convert the array of dictionaries to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kapaa  22.0752 -159.3190     79.12        85          40       16.11
# 1     Katsuura  35.1333  140.3000     82.92        82           2       14.79
# 2    Jamestown  42.0970  -79.2353     62.71        75           0        3.44
# 3       Shache  38.4167   77.2406     93.07        17         100       11.72
# 4   Bredasdorp -34.5322   20.0403     55.26        53          87        5.39
# 5   Kaitangata -46.2817  169.8464     40.68        92          78        7.45
# 6   Oranjemund -28.5500   16.4333     57.63        51           4       11.56
# 7      Paamiut  61.9940  -49.6678     42.78        92          97        7.36
# 8        Bluff -46.6000  168.3333     45.75        78          21       11.25
# 9  Providencia  28.7167 -111.5833     83.21        84          98        7.00
#
#   Current Description Country                 Date
# 0    scattered clouds      US  2022-07-31 08:45:12
# 1           clear sky      JP  2022-07-31 08:45:12
# 2                 fog      US  2022-07-31 08:41:33
# 3     overcast clouds      CN  2022-07-31 08:45:13
# 4     overcast clouds      ZA  2022-07-31 08:45:14
# 5       broken clouds      NZ  2022-07-31 08:45:15
# 6           clear sky      NA  2022-07-31 08:45:15
# 7     overcast clouds      GL  2022-07-31 08:45:16
# 8          few clouds      NZ  2022-07-31 08:45:16
# 9     overcast clouds      MX  2022-07-31 08:45:17

# %%
# Reorder the columns in the DataFrame. 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kapaa      US  22.0752 -159.3190     79.12        85          40
# 1     Katsuura      JP  35.1333  140.3000     82.92        82           2
# 2    Jamestown      US  42.0970  -79.2353     62.71        75           0
# 3       Shache      CN  38.4167   77.2406     93.07        17         100
# 4   Bredasdorp      ZA -34.5322   20.0403     55.26        53          87
# 5   Kaitangata      NZ -46.2817  169.8464     40.68        92          78
# 6   Oranjemund      NA -28.5500   16.4333     57.63        51           4
# 7      Paamiut      GL  61.9940  -49.6678     42.78        92          97
# 8        Bluff      NZ -46.6000  168.3333     45.75        78          21
# 9  Providencia      MX  28.7167 -111.5833     83.21        84          98
#
#    Wind Speed Current Description
# 0       16.11    scattered clouds
# 1       14.79           clear sky
# 2        3.44                 fog
# 3       11.72     overcast clouds
# 4        5.39     overcast clouds
# 5        7.45       broken clouds
# 6       11.56           clear sky
# 7        7.36     overcast clouds
# 8       11.25          few clouds
# 9        7.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"
# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file)
